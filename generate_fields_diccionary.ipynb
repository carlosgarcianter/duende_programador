# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosgarcianter/duende_programador/blob/main/generate_fields_diccionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # lista

# %%
lista_columnas = ["last_daily_run_timestamp", "last_daily_run", "last_run", "deleted", "name", "process_type",
                "data_label", "description", "exceptions_workflow", "masking", "last_run_user_id", "process_status",
                "creation_timestamp", "url_string", "result_id", "record_id", "url_id", "run_id", "status", "score",
                "update_timestamp", "process_id", "input", "roll_up_relationship", "run_number", "pass_name",
                "deleted_match_occurrence_id", "deleted_unmatched_occurrence_id", "s_ccp_id", "s_producto_familia",
                "s_producto_grupo", "s_producto_tipo", "s_contrapartida", "s_contrapartida_descripcion",
                "d_fecha_pago_liquidacion", "f_importe_pago", "cf_f_diferencia_importe", "s_sentido",
                "s_tipo_fijo_variable", "s_tipo_flujo", "s_divisa", "s_id_boleta", "s_origen", "s_criterio_agrupacion",
                "rr_f_reset_rate", "cf_dt_fecha_descuadre", "rl_s_id_platform", "rr_s_id_mx3_star", "s_side", "s_isin",
                "rr_s_roll_up_mx", "s_pase_1__id_mercado_", "s_pase_2__id_mercado_", "s_pase_3__ion_id_",
                "s_pase_4__block_id_", "s_pase_5__clave_econ_mica_", "s_id_mot", "s_trade_date", "s_maturity_date",
                "s_value_date", "f_nominal", "f_price", "f_clean_price", "f_dirty_price", "s_currency",
                "s_portfolio_mx", "s_portfolio_st", "s_contrapartida_mx_interna", "s_contrapartida_ion", "cf_s_mesa_mx",
                "cf_s_mesa_interna_mx", "cf_s_mesa_st", "rl_s_trader_sales", "rl_s_id_destino", "rl_s_id_deal_manager",
                "rl_s_insert_time", "rr_s_portfolio", "rr_s_contrapartida", "rr_s_nominal", "rr_s_bloque_id",
                "rl_s_cruce_al_campo_id___ion", "cf_s_calculated_entity_rc", "cf_s_calculated_etiqueta_bbva_2",
                "rr_s_indicador_interna", "rl_s_blkid", "rl_i_accrued_coupon", "rl_s_fechaetiqueta",
                "rl_dt_fecha_y_hora_bbg", "rl_s_mercado_bbg_1", "rl_s_mercado_bbg_2", "rl_s_id_bbg",
                "rl_s_id_marketaxess", "rl_s_fecha_y_hora_marketaxess", "cf_s_status_description",
                "s_bofs_operation_code_senaf", "s_id_hdat", "s_inquiry_id_marketaxess", "s_ordernumber_brokertec",
                "s_product_tradeweb", "s_trade_date_tradeweb", "s_trade_id_marketaxess", "s_trade_id_mts",
                "s_trade_ids_tn_bondvision", "s_trade_number_tradeweb", "cf_f_nominal_crv_eur_plataformas",
                "cf_f_nominal_crv_eur_mx_star", "rr_s_tv_transaction_id", "cf_s_error_detail_ion",
                "rl_s_pase_4_plataformas_b_id_", "cf_s_id", "rr_s_field_14", "s_portfolio_star", "s_portfolio_calypso",
                "s_mesa", "f_nominal_amort", "rr_d_trade_settle_date", "cf_s_totalmente_amortizada",
                "rl_f_porcentaje_amortizacion", "rl_f_nominal_amort_star", "rr_d_maturity_date",
                "cf_dt_fecha_del_descuadre", "rl_s_fecha_contratacion", "rl_s_id_star", "rr_s_trade_id_calypso",
                "rl_d_fecha_valor", "f_nominal_crv_eur", "f_nominal_amort_crv_eur", "cf_i_calculated_result_3",
                "s_id_front", "s_ccp___short", "d_fecha_de_registro", "d_start_date", "d_end_date", "f_npv", "s_fo_id",
                "s_markit_id", "s_sistema_de_origen", "s_codigo_fo_de_contrapartida_match",
                "s_nombre_de_la_contrapartida", "s_uti", "s_tipo_fijo_pata_pago", "s_ind_ref_pata_pago_conciliacion",
                "rl_s_ind_ref_pata_de_pago_fo", "rr_s_ind_ref_pata_de_pago_sernova", "s_spread_pata_de_pago",
                "s_tipo_fijo_pata_cobro", "s_ind_ref_pata_cobro_conciliacion", "rl_s_ind_ref_pata_de_cobro_fo",
                "rr_s_ind_ref_pata_de_cobro_sernova", "s_spread_pata_de_cobro", "f_npv_crv_eur", "s_divisa_npv",
                "rr_d_fecha_datos", "cf_d_fecha_de_proceso", "cf_d_ageing_started_at",
                "rl_s_codigo_fo_de_contrapartida", "rr_s_camara", "s_house_or_client", "s_producto", "s_noperacionstar",
                "s_portfolio", "f_cantidad", "f_efectivo_inicial", "s_fecha_valor", "f_rate_type", "rr_s_n_ope_calypso",
                "rl_s_cpd_cd", "cf_dt_fecha_de_descuadre", "rl_s_val_vdo_ff", "f_efectivo_inicial_crv_eur",
                "rl_s_obs_tx", "rr_s_trade_keyword__referencebond", "s_id_impact", "s_id_calypso", "s_cusip",
                "d_settlement_date", "s_trader", "s_product_subtype", "s_buy_sell", "f_principal_amount",
                "f_efectivo_vuelta", "f_interest_amount", "f_principal_amount_crv_eur", "s_counterparty", "s_book",
                "s_product_type", "rr_s_desk", "rr_s_maturity_type", "rr_s_cash_rate_type", "rr_f_internal_repo_rate",
                "rr_s_underlyingproduct_codeisin", "rr_s_counterpartyshort_name", "s_source", "rr_s_id_back",
                "s_codigo_contrapartida", "s_interna", "s_tipologia", "d_trade_date", "d_value_date",
                "s_fecha_vencimiento", "f_rate_type_0", "s_status", "s_divisa_liquidacion", "rr_s_buycomment1",
                "cf_s_justificaci_n_y_n", "cf_s_suma_justificaciones", "s_system_bbva__st_mx_", "s_markitid",
                "rr_s_trade_id", "s_product", "s_counter_party_original", "cf_s_check_counterparty_bilateral",
                "s_counterpartybilateral", "s_counterpartybilateraloriginal", "rr_s_bbva_trader_id", "s_breakyesno",
                "s_breakoption", "d_breakfirstdate", "s_breakexpiratiodateperiod", "s_breakfrequency",
                "d_maturity_date", "f_notional", "f_notional_2", "s_currency_2", "s_payment_frequency",
                "s_payment_frequency_2", "s_legal_rate_index", "s_legal_rate_index_2", "s_day_count_basis",
                "s_day_count_basis_2", "f_spread_over_floating", "f_spreadoverfloating2", "s_collateralizationtype",
                "s_option_style", "s_option_type", "f_prima", "s_strike", "s_executionvenuetype", "s_contractstate",
                "s_convenci_n_d_a_h_bil", "s_holidays", "s_mtm", "s_sistema", "rr_s_family", "s_asset_class",
                "rr_s_group", "rr_s_typology", "rr_s_platformdesc", "rl_s_singlesided", "rl_dt_extractdatetime",
                "rr_s_payreceive1", "rr_s_payreceive2", "rr_s_leg1fixvar", "rr_s_leg2fixvar",
                "rl_s_privatebookingstate", "rr_d_valdate", "rl_d_enddate", "cf_s_justifiacion_irs___mat_date",
                "cf_f_notional_1_crv_eur", "cf_f_notional_2_crv_eur", "cf_s_justificaci_n_error_en_fichero",
                "s_clave__nica_portfolio", "s_clave__nica_mesa", "f_position", "f_position_absolute", "rr_s_libro_star",
                "cf_s_emision_amortizada", "cf_f_factor_amortizacion", "s_clave_gen_rica_mesa",
                "cf_f_posici_n_calypso_crv_eur", "cf_f_posici_n_star_crv_eur", "i_entidad", "s_pa_s", "s_iuc",
                "d_fecha_valor__ltimo_movimiento_recibido", "s_c_digo_de_situaci_n", "i_n_mero_de_movimientos_recibido",
                "s_tipo_de_registro", "i_contrapartida", "d_fecha_proceso", "d_fecha_de_entrada_en_mora",
                "f_importe_exigible", "rl_s_aplicaciondestino", "d_fecha_valor",
                "f_importe_del_movimiento_en_la_divisa_del_contrato", "i_identificador__nico_de_movimiento_ircm",
                "s_n_mero_de_cuota", "i_acci_n", "i_concepto", "i_caracter_stica", "i_operaci_n", "d_eod",
                "s_aplicacion_destino", "s_oficina", "d_fecha_valor_contrato", "d_fecha_valor_movimiento",
                "d_fecha_contable_movimiento", "s_tipo_de_movimiento", "s_id_movimiento_ircm", "f_importe", "i_folio",
                "s_estado_movimiento", "s_tipo", "s_metodo_de_liquidacion", "s_liquidacion", "s_enterprise", "s_pais",
                "s_id", "s_productocruce", "s_input", "s_workflow", "s_codimporte", "s_etiquetas_pencru",
                "s_marca_transitorias", "s_operacionmasa", "s_marcafobo", "s_codtipprod", "s_group", "s_assigned_to",
                "f_apuntes", "s_age_as_at_export", "s_grupocruce", "f_dc2financing", "f_dc3efectofx", "f_dc4tipocambio",
                "f_dc5autocartera", "f_plmeseur", "f_plcajasmeseur", "s_importe", "s_plmeseur", "s_plcajasmeseur",
                "s_grupo_cruce", "s_producto_cruce", "s_codigo_importe", "f_pl_mes_eur", "f_pl_resultado_contable",
                "f_dc2_financing", "f_dc3_efecto_fx", "f_dc4_tipo_cambio", "f_pl_aj_totem_eur", "f_pl_cajas_mes_eur",
                "f_pl_valoracion_mes_eur", "i_apuntes", "s_comentario_ajuste", "s_usuario_ajuste", "i_pencru",
                "s_comentario_pencru", "f_ajustes_masivos_boco", "f_ajustes_masivos_recla", "f_ajustes_masivos_resto",
                "f_resultado_aplicaciones_bo_aux", "f_de_diferencias_explicadas_aux",
                "f_dc1_diferencia_de_perimetro_aux", "f_de2___ajustes_masivo_aux", "cf_f_dc21_ajustes_de_grmu",
                "s_numfront", "s_lado_origen", "s_tipologia_de_mercado", "s_m_instrument", "s_divisa_origen",
                "s_divisa_importe", "f_ajustes_manuales_7250_signo_aux", "f_ajustes_manuales_7250_boco_aux",
                "f_ajustes_manuales_7250_recla_aux", "f_ajustes_manuales_7250_resto_aux",
                "f_resultado_contable_publicado_aux", "rl_s_agrup", "rl_s_apl_ori_cd", "rl_s_prodgest",
                "rl_s_marca_publicable", "rl_s_marca_comparable", "rl_s_marca_autocartera", "rl_s_und_cd",
                "rl_s_contrapartida", "rl_s_oficina_unidad", "rl_s_oficina_contrapartida", "rr_s_tipprocedencia",
                "rr_s_tipcontrato", "rr_s_contrato", "rr_s_cuenta", "rr_s_servcreador", "rr_s_aplicacionorigen",
                "rr_s_clasificacion_cuenta", "cf_f_dc22_asimetria_old", "cf_f_diferencias_no_explicadas",
                "rl_s_comentario_ajuste_ge", "cf_f_dc_diferencias_de_criterio", "cf_s_marca_transitorias",
                "cf_s_marca_fobo", "cf_s_operacion_masa", "rr_s_oficina", "rr_s_tipo_boco",
                "f_resultado_sigma_perimetro_comparable_aux", "f_resultado_sigma_perimetro_publicable_aux",
                "rr_s_tipologia_boco", "cf_f_ajustes_manuales_7250_boco", "cf_f_ajustes_manuales_7250_recla",
                "cf_f_ajustes_manuales_7250_resto", "rr_s_codimporte", "cf_f_de2_ajustes_masivos",
                "cf_f_de_diferencias_explicadas", "cf_f_de1_ajustes_7250", "cf_f_ajustes_manuales_7250_signo",
                "cf_f_resultado_contable_publicado", "cf_f_ajustes_masivos",
                "cf_f_resultado_sigma_perimetro_comparable", "cf_f_resultado_aplicaciones_bo",
                "cf_f_resultado_sigma_perimetro_publicable", "cf_i_de3_otros", "cf_f_dc1_diferencia_de_per_metro",
                "f_de1_ajustes_7250_aux", "f_ajustes_masivos_aux", "s_clasificaci_n_de_ajuste", "f_asimetrias_mmoo",
                "cf_f_dc22_asimetria", "f_dc7_intimas", "f_dc8_red_minorista", "f_de1_ajustes_7250",
                "f_de2_ajustes_masivos", "f_dc11_operativa_domestica", "f_prima_de_liquidez",
                "f_ajustes_manuales_7250_boco", "f_ajustes_manuales_7250_recla", "f_ajustes_manuales_7250_resto",
                "f_ajustes_manuales_7250_signo", "f_ajustes_masivos", "s_codorigen", "f_de_diferencias_explicadas",
                "i_de3_otros", "f_resultado_aplicaciones_bo", "f_resultado_contable_publicado",
                "f_resultado_sigma_perimetro_comparable", "f_resultado_sigma_perimetro_publicable", "i_pencru_aux",
                "cf_f_dc9_valora_no_valora", "s_marcamacrocobertura", "s_marcavalora", "s_cartera", "cf_f_dc10_macro",
                "cf_f_dc19_estructurados_eur", "cf_f_dc1_diferencia_de_perimetro", "rr_s_divisa",
                "rr_s_numfronttratado", "rr_s_isin", "rr_s_clasificacioncuenta", "rr_s_cartera", "rr_s_tipoboco",
                "i_dc9aux", "i_dc10aux", "f_macro_coberturas", "s_divisaoperacion",
                "f_dc17_anulaci_n_p_l_sigma_comparable", "f_dc18_alta_p_l_valoraci_n_sigma",
                "f_dc_diferencias_de_criterio", "rr_s_aplicacion", "rr_s_prodgest", "rr_s_pfmarcapublicablemad",
                "rr_s_pfmarcacontable", "rr_s_oficinaunidad", "rr_s_oficinacpty", "rr_s_comentarioajustege",
                "rl_s_tiprocedencia", "rl_s_oficina", "rl_s_cuenta", "rl_s_servcreador", "rl_s_tipoboco",
                "rl_s_tipologiaboco", "s_aplicacionorigen", "rl_s_contrato", "s_filler1", "s_filler2", "i_dc5_aux",
                "rl_s_oficinaunidad", "rl_s_oficinacpty", "rr_i_tiprocedencia", "rr_i_tipcontrato",
                "cf_f_dc5_autocartera", "rl_s_marcaautocartera", "rl_s_codimporte", "f_dc13_dop_sla", "s_pencru_aux",
                "s_numfronttratado", "s_agrupa", "s_oficinaunidad", "s_oficinacpty", "s_instrumento",
                "s_marca_comparable", "s_marca_publicable", "s_comentario_ajuste_ge", "s_contrato", "s_tiprocedencia",
                "s_tipcontrato", "f_dc14_anulacion_cajas", "f_dc15_liquidaciones_mes",
                "f_pl_valoracion_comparable_mes_eur", "f_dc4s_tipo_cambio_valoracion_eur",
                "f_dc16_liquidaciones_8238_8239", "f_pl_resultado_bo_valoracion_eur",
                "f_pl_ajustes_7250_valoracion_eur", "f_pl_ajustes_masivos_valoracion_eur",
                "f_dc4m_tipo_cambio_cajas_eur", "s_clasificacion_de_ajuste", "i_marcavalora",
                "f_resultado_sigma_perimetro_comparable_revaluacion", "rr_s_coddiv", "rr_s_estructura",
                "rr_s_carteraactual", "rr_s_carteraanterior", "cf_f_resultado_sigma_comparable_rof",
                "s_numfront_tratado", "s_apl_ori_cd", "rl_s_m_instrument", "rl_s_pto_ges_cd", "s_marca_contrapartida",
                "s_marca_clearing", "rr_s_tiprocedencia", "s_marca_valora", "s_estructura",
                "f_pl_acuval_eur_sigma_hist", "f_dc4s_tipo_cambio_valoraci_n_eur", "f_dc4c_pl_dif_tipocambio_cajas_eur",
                "f_dc4v_pl_dif_tipocambio_valoracion_eur", "cf_f_dc12_operativa_clearing",
                "cf_f_dc20_operativa_primary_opv", "cf_f_dc22_asimetr_a", "cf_s_etiquetas_pencru",
                "cf_s_comentario_pencru", "f_de2_ajustes_masivos_aux", "i_dc9_aux", "i_dc12_aux", "i_dc21_aux",
                "f_red_comercial", "s_dc6ajustesliqamiga", "s_de1ajustes7250", "s_de2ajustesmasivos",
                "s_plresultadocontable", "s_plvaloracionmeseur", "s_resultado_sigma_perimetro_publicable",
                "s_resultado_contable_publicado", "f_dcdiferencias_de_criterio", "f_dediferencias_explicadas",
                "s_diferencias_no_explicadas", "s_dc1_diferencia_de_perimetro", "s_ajustes_manuales_7250_signo",
                "s_ajustes_masivos", "s_ajustes_manuales_7250_boco", "s_ajustes_manuales_7250_recla",
                "s_ajustes_manuales_7250_resto", "s_ajustes_masivos_boco", "s_ajustes_masivos_recla",
                "s_ajustes_masivos_resto", "f_de3otros", "s_labels", "f_dc1_diferencia_de_perimetro", "rl_s_aplicacion",
                "rl_s_numfrontsigma", "rl_s_pfmarcapublicablemad", "rl_s_pfmarcacontable", "rl_s_numfronttratado",
                "rl_s_undcd", "rl_s_isin", "rl_s_instrumento", "rr_i_cuenta", "rr_d_fecha_vencimiento",
                "rr_s_divisa_origen", "f_dc5_autocartera", "f_pl_mes_eur_dividendos", "f_dc6_ajustes_liq_amiga",
                "rl_s_numfront", "rl_s_portfolio", "f_dc17_anulacion_p_l_sigma_comparable",
                "f_dc18_alta_p_l_valoracion_sigma", "s_clasificaci_n_de_apunte", "f_resultado_bo_rof",
                "f_resultado_bo_revaluacion", "f_resultado_sigma_perimetro_comparable_rof",
                "f_resultado_sigma_perimetro_publicable_rof", "f_resultado_sigma_perimetro_publicable_revaluacion",
                "f_micro_coberturas", "rl_s_productocruce", "rl_s_divisaoperacion", "rl_s_agrupa", "rl_f_importe",
                "rl_s_coddiv", "rl_s_codorigen", "rl_s_grupocruce", "rl_s_conceptocgpfolio",
                "rl_s_fechavencimientocaratulas", "rl_s_comentarioajustege", "rr_f_importe", "rr_s_codorigen",
                "rr_s_grupocruce", "rr_s_tipologiaboco", "rr_d_fechavencimiento", "i_banco", "s_cuenta", "s_banco",
                "d_fcontable", "s_desglose", "cf_s_divisa", "s_sc", "s_scori", "s_texto", "s_indiregu",
                "cf_s_regularizador", "f_plgs__p_l_sigma_agregado", "s_agrup", "s_und_cd", "rl_s_concepto_cg_pfolio",
                "i_tipcontrato", "f_strike", "s_vencimiento", "f_valor_mercado", "s_putcall", "s_clearer",
                "f_precio_de_cierre", "f_t_tulos", "s_c_mara", "f_resultado_bo_revaluaci_n",
                "f_resultado_sigma_comparable_revaluaci_n", "s_prod_cruce", "rl_s_prod_gest", "rl_s_oficina_cpty",
                "rl_s_pf_marca_publicable_mad", "rl_s_pf_marca_contable", "cf_f_resultado_bo_rof", "f_oca",
                "rl_s_pf_marca_publicable_mad_", "rr_s_tipolog_a_boco", "rl_s_cod_origen", "rr_s_cod_importe",
                "f_resultado_sigma_comparable_rof", "f_resultado_sigma_comparable_revaluacion", "rl_s_codtipprod",
                "rr_s_codtipprod", "rr_s_fechavencimiento", "s_prod_cruce_", "rr_s_numfront_tratado",
                "rr_s_cartera_actual", "i_dc19_aux", "d_fecha", "d_fechaflujo", "s_clavecruce",
                "s_productoconciliacion", "f_posfoconciliable", "f_posicionfront", "f_posicioncontable",
                "f_posicionback", "f_ajustesmasivos", "f_ajustes7250", "f_diferenciascriterioco",
                "f_dc1primadeopciones", "f_dc2rollover", "f_dc3periodificacion", "f_decalajecrucetun", "f_diferencias",
                "f_diferenciasexplicadas", "f_diferenciasnoexplicadas", "f_dividendoneto", "f_fixing",
                "f_diferenciasnoexplicadaseur", "rl_f_importe_p_l", "rl_f_importe_multidivisa", "rl_f_importe_mto_m_1",
                "rl_s_dc4_ajvr_sc511", "s_estado", "f_diferenciascriteriofo", "s_isin_nfront", "d_run_date",
                "i_contador", "cf_s_umbral_materialidad", "cf_s_tipificacion", "cf_s_backlog_historico",
                "cf_s_estado_backlog", "cf_s_umbral_backlog", "cf_s_umbrales", "cf_s_clasificacion",
                "cf_s_ajuste_7250_masivos", "cf_s_diferencia_cero_purgas", "cf_s_diferencia_de_criterio_mmoo",
                "cf_s_fobo___conci_11", "cf_s_fobo___conci_14", "cf_s_fobo___conci_28", "cf_s_fobo___conci_53",
                "cf_s_fobo___conci_72", "cf_s_fobo___conci_138_isin", "cf_s_fobo___conci_139", "cf_s_umbrales_divisa",
                "cf_s_fobo___conci_5_isin", "cf_s_fobo___conci_138_n__operacion", "cf_s_decalaje", "s_comentariomanual",
                "f_ajustes7250_crv_eur", "f_diferenciascriterioco_crv_eur", "f_ajustesmasivos_crv_eur",
                "f_backlog_hist_ajuste_7250", "f_backlog_hist_ajustesmasivos", "cf_f_saldo_pencru_div",
                "cf_f_saldo_pencru_euros", "cf_s_porcentaje_explicado_saldo_pencru", "f_abs_eur__diferencia_",
                "f_diferenciasnoexplicadasabs", "cf_s_label_hist_rica", "f_resultado_sigma_comparable_revaluaci_n_aux",
                "cf_f_resultado_sigma_comparable_revaluaci_n", "f_resultado_bo_revaluaci_n_aux",
                "cf_f_resultado_bo_revaluaci_n", "cf_f_resultado_bo_rof_aux", "cf_f_resultado_sigma_comparable_rof_aux",
                "rr_s_prod_gest", "rr_s_pf_marca_publicable_mad", "rr_s_pf_marca_contable", "rr_s_und_cd",
                "rr_s_oficina_unidad", "rr_s_oficina_cpty", "rr_s_comentario_ajuste_ge_", "rl_s_tipo_boco",
                "rl_s_tipologia_boco", "rl_s_cod_importe", "rl_s_numfront_tratado", "rr_s_fecha_vencimiento",
                "f_importe_", "d_fecha_cierre", "cf_d_fecha_cierre_fecha", "s_chk", "s_vinculada", "s_codjeraquico",
                "s_macroepigrafe", "s_neocon", "s_procedencia", "s_importedivisa_formato_texto",
                "cf_f_importedivisa_formato_num", "s_signo", "s_descripci_n", "s_usuario", "s_screador", "s_asiento",
                "s_claseasiento", "s_codigoapunte", "s_centrocoste", "s_refcruce", "s_centrogasto",
                "s_fechamodif_formato_texto", "cf_d_fecha_modif_fecha", "s_horamodif", "cf_t_horamodif_hora",
                "s_motivo", "s_peticionario", "s_fecha_fichero", "rr_d_fecha_contable", "rr_s_texto", "rr_s_sc",
                "rr_s_scori", "rr_s_indiregu_aux", "cf_f_importe_", "cf_d_fecha_cierre_", "s_codjerarquico",
                "cf_f_importe_divisa_", "s_descripcion", "cf_d_fecha_modif", "cf_t_horamodif_", "d_fecha_cierre_aux",
                "s_importe__aux", "s_importedivisa_aux", "d_fechamodif_aux", "s_horamodif_aux", "d_fecha_contable",
                "s_regularizador", "s_id_operaci_n", "s_sort_clave", "s_tipo_de_flujo", "s_cobro_pago",
                "f_importe_flujo", "s_divisa_de_liquidaci_n", "rl_f_importe_ajustabilidad", "rl_s_divisa_ajustabilidad",
                "f_importe_nominal", "f_tipo_inter_s", "d_fecha_inicio", "d_fecha_fin", "d_fecha_liquidaci_n",
                "d_fecha_fijaci_n", "s_grupo_producto", "cf_d_fecha_sistema_duco", "rl_s_producto_star", "rl_s_f_v",
                "rl_s_subyacente", "rl_s_estrategia", "f_importe_flujo_crv_eur", "f_importe_nominal_crv_eur",
                "cf_dt_fecha_descruadre", "rl_s_subtipo_1", "rl_s_subtipo_2", "rl_s_subtipo_3", "rl_s_subtipo_4",
                "rl_s_subtipo_5", "rr_s_compound_interest_amount", "s_n_mero_operaci_n", "s_entidad",
                "rr_s_product_type", "f_nominal_cobro", "s_divisa_cobro", "f_nominal_pago", "s_divisa_pago",
                "d_fecha_contrataci_n", "d_fecha_vencimiento", "rr_d_fecha_liberaci_n", "rl_s_hora_liberaci_n",
                "s_mirror_trade", "rr_s_pay_leg_type", "rr_s_rcv_leg_type", "rl_s_estructura", "rr_s_operation_type",
                "s_direction", "d_expiration_date", "s_price_currency", "s_strike_price", "s_venue_of_execution",
                "f_cash_flow", "s_divisa_flujo", "f_importe_ajuste", "s_divisa_ajuste", "f_tipo_de_interes",
                "rr_s_mirror_trade", "s_subyacente", "d_fecha_fijaci_n_tipo_de_cambio", "s_fijo_variable",
                "rl_s_expiry_date", "rl_s_rate_tipo_de_cambio", "rr_s_trade_keyword__mirrorportfolio",
                "s_counterparty_1", "f_valuation_amount", "s_level", "s_clasificacioncuenta", "s_divisaimporte",
                "s_divisaorigen", "s_servcreador", "s_tipoboco", "s_tipologia_boco", "s_aploricd",
                "s_comentarioajustege", "s_tipprocedencia", "s_conceptocgpfolio", "s_prodgest",
                "s_pfmarcapublicablemad", "s_pfmarcacontable", "s_ladoorigen", "s_tipologaboco", "s_undcd",
                "s_marcacomparable", "s_marcapublicable", "s_aplicacion", "s_codigoimporte", "s_minstrument",
                "s_marcaautocartera", "s_tipologiademercado", "s_tipologiaboco", "s_grupocruce_2", "s_grupocruce_8",
                "s_internal_deal", "s_tipo_de_producto", "d_payment_day", "s_p_r", "rr_s_productcodeisin", "rr_s_cre",
                "f_cash_flow_crv_eur", "i_comentario_contrato_aux", "s_bs", "i_tkt", "rr_s_mirror_trade_id",
                "s_clave_de_cruce", "s_unidad_star", "f_tipo_de_inter_s", "d_fecha_start_date", "rl_s_fecha_liberaci_n",
                "s_c_digo_estructura", "rr_s_interna", "rl_s_n_operaci_n", "rr_s_internal_reference", "d_transac",
                "d_mty_date", "f_price_with_decima", "f_amount", "s_valuation_currency", "f_strike_price",
                "s_prior_uti", "s_underlying_identification", "f_delta", "dt_execution_timestamp",
                "f_notional_amount_of_leg_1", "s_notional_currency_1", "f_total_notional_quantity_of_leg_1",
                "s_marcacontrapartida", "s_marcaclearing", "s_central_counterparty", "cf_s_calculated_uti",
                "s_collateral_portfolio_code", "rr_i_cuentaaltura", "d_a_la_fecha", "f_precio", "i_monto",
                "s_fecha_vencimiento__revisar_", "s_contraparte", "s_ro_primario_isin", "s_recibir_divisa__revisar_",
                "s_fecha_de_liquidacin_al_mismo_da_de_cds", "i_boleta___diccionario__", "s_ctrpt__revisar_",
                "i_boleta___necesita_diccionario__", "s_fecha_fijaci_n", "f_importe_del_flujo",
                "f_importe_del_flujo_crv_eur", "rl_s_n__operaci_n_front_office", "rr_s_n__operaci_n_back_office",
                "s_internal_reference", "f_importe_cobro", "s_div_cobro_star__bo___pago_mx",
                "s_div_pago_star__bo___cobro_mx", "rl_f_tipo_de_cambio", "rr_d_front_system_date",
                "cf_s_hora_liberaci_n", "s_contrapartida_1", "s_contrapartida_2", "rr_s_calypso_buy_sell",
                "rr_s_origen", "rl_s_origen", "f_importe_cobro_crv_eur", "f_importe_pago_crv_eur", "rl_s_usuario_alta",
                "s_estrategia", "d_fecha_de_pago", "f_importe_de_flujo", "cf_f_diferencia_de_importe",
                "s_n_mero_de_boleta", "cf_s_campo_status", "rl_d_m_tp_dtetrn", "rr_d_m_tp_dtetrn", "rl_s_evento",
                "rr_s_evento", "rl_s_fecha_vencimiento", "rl_s_flwsubtype", "rr_s_flwsubtype",
                "f_importe_de_flujo_crv_eur", "rl_s_codorigen1", "rr_s_ladoorigen", "rl_s_flownat", "rl_s_murex",
                "rl_i_mnb", "rl_i_mcontract", "rl_s_mtrnfmly", "rl_s_mtrngrp", "rl_s_mtrntype", "rl_s_mdtflwtyp0",
                "rl_s_mdtflwtyp1", "rl_s_mdtflwtyp2", "rl_s_type4", "rl_i_mdtphase", "rl_i_leg", "rl_f_rate",
                "rl_f_nominal", "rl_f_cashfflow", "rl_s_pr", "rl_s_currencyflow", "rl_f_mdtoamt0", "rl_s_mdtcapcur0",
                "rl_d_trade_date", "rl_d_start_date", "rl_d_end_date", "rl_d_payment_date", "rl_s_mirror",
                "rl_s_mtpint", "rl_s_mtppfolio", "rl_s_mtpcntrpid", "rl_s_mdtindex10", "rl_s_strategy",
                "rl_d_fecha_fijaci_n", "rl_s_status", "rl_d_fecha_fijaci_n_tipo_de_cambio_mx", "rl_f_margin",
                "rr_s_book", "rr_s_processing_orgfull_name", "rr_s_external_reference", "rr_s_tradekeywordsentby",
                "rr_s_tradekeywordselleraccountreference", "rr_s_tradekeywordcounterpartyid",
                "rr_s_descripci_n_contrapartida", "rr_s_trade_date", "rr_s_c_digo_estructura", "rr_s_cash_flow_type",
                "rr_f_cash_flow_reset_rate", "rr_f_cashflow_notional", "rr_f_cash_flow_amount", "rr_s_payrcv",
                "rr_s_cash_flow_ccy", "rr_d_pmt_begin", "rr_d_pmt_end", "rr_d_cash_flow_date", "rr_s_internal_deal",
                "rr_d_cash_flow_reset_date", "rr_s_fixed", "rr_s_rate_index_1", "rr_f_cash_flow_amount_in_base_ccy",
                "rr_s_cash_flow_notional_ccy", "rr_d_cash_flow_fx_reset_date", "rr_f_compound_interest_amount",
                "rr_d_cmp_start", "rr_d_cmp_end", "rr_f_index_spread", "rr_f_cash_flow_fx_rate",
                "s_tipo_de_flujo_principal_adj", "s_st_secundario", "f_posicion", "rr_i_id_murex", "rr_d_trade_date",
                "s_flujo_compuesto", "i_contract_id", "f_value", "f_all_in_value", "f_haircut", "s_haircut_rule",
                "s_collateral_type", "s_segregated", "s_triparty_agent", "s_rehypotecable", "s_ownership",
                "s_pay_receive", "s_custodio_account_number", "s_flujos_finales_filtro", "d_fecha_aparicion",
                "rl_s_pf_marca_publica_ble_mad", "f_dc13___dop_sla", "rr_s_comentario_ajuste_ge", "rl_s_tipolog_a_boco",
                "f_cartera", "cf_f_resulado_sigma_comparable_rof_aux", "s_acci_n", "s_concepto", "s_caracter_stica",
                "s_operaci_n", "s_identificador__nico_de_movimiento_ircm", "rl_f_impexigible", "rl_s_coddiisoalf",
                "rl_s_coddivisa", "s_securitycurrency", "s_passthrough", "s_type", "s_cashfrequency", "f_cleanprice",
                "d_tradesettledate", "s_mnbext", "i_mnb", "f_quantity", "f_efectivo", "s_indexname", "f_fixedrate",
                "f_spread", "s_mtpbuy", "s_daycount", "s_pfolio", "s_mtpcntrp", "s_mnb", "rl_i_codrdr",
                "rl_s_productofront", "rl_s_productoback", "rl_s_codtipdatcab", "s_field_34", "s_field_30",
                "s_field_26", "s_field_27", "s_field_28", "s_field_29", "b_field_31", "s_field_32", "s_field_33",
                "s_field_35", "s_field_36", "i_field_37", "f_field_38", "f_field_39", "s_field_40", "f_field_41",
                "s_field_42", "s_field_43", "f_field_44", "s_field_45", "f_field_46", "s_field_47", "s_field_48",
                "s_field_49", "s_field_2", "s_casflow_days", "s_cash_class", "s_type_conf", "s_flow_type",
                "b_manual_amount", "s_cashflow_period", "s_fixed_rate", "s_float_rate", "i_index_factor",
                "f_index_spread", "f_final_rate", "s_reset_date", "f_cf_notional", "s_cash_index", "s_index_term",
                "f_pv_discount", "s_discount_factor", "f_fx_rate", "s_sec_curr", "s_delivery_type", "s_nb",
                "f_posicion_factorizadacon_signo", "s_productcodeisin", "s_bkattrfinancedesk", "f_jul_2_2024",
                "s_bs_____callput_tiene_c_y_v__podr_a_ser_compra_venta_", "f_principal", "f_net_amount", "d_stldate",
                "f_resultado_sigma_comparable_revaluacion_aux", "f_resultado_bo_revaluacion_aux",
                "cf_f_resultado_bo_revaluacion_", "cf_f_resultado_sigma_comparable_revaluacion", "i_boleta", "s_cntrpt",
                "d_mtty", "s_monto", "s_nocional", "s_recibir_divisa", "s_identificador_nico_de_swap_para_compensacin",
                "s_identificador_nico_de_swap_para_operacin", "s_precio", "rl_d_a_la_fecha", "rl_i_boleta",
                "rl_s_descripcin_de_valor", "rl_s_operador", "rl_s_bs", "rl_i_monto", "rl_s_precio", "rl_s_tipo",
                "rl_s_ticker", "rl_s_contraparte", "rl_s_identificador_nico",
                "rl_s_identificador_nico_de_swap_para_compensacin", "rl_s_identificador_nico_de_swap_para_operacin",
                "rl_s_cuenta_de_firma", "rl_s_tipo_de_restructuracin", "rl_s_spread_plano_cds",
                "rl_d_fecha_de_liquidacin_al_mismo_da_de_cds",
                "rl_s_cdigo_par_de_datos_de_la_entidad_de_referencia_cds", "rl_s_tipo_de_deuda_de_la_obligacin",
                "rl_d_efectiva", "rl_d_fecha_vencimiento", "rl_d_fecha_de_negociacin_original",
                "rl_i_monto_nocional_pag", "rl_s_recibir_divisa", "rl_i_spread_swap", "rl_i_recibir_monto_nocional",
                "rl_s_tipo_swap", "rl_s_cds_irs_estado_de_compensacin", "rr_d_mdatecmp", "rr_s_mtimecmp",
                "rr_s_mrefoblig", "rr_s_minstrument", "rr_i_mnb", "rr_s_curr0", "rr_s_curr1", "rr_i_mtimecmp_2",
                "rr_i_mtimecmp_3", "rr_s_mtpae", "rr_s_tpcntrp", "rr_s_mtpcp", "rr_d_mtpdtesys", "rr_d_mtpdtetrn",
                "rr_i_mtpaccsct", "rr_s_mtppfolio", "rr_s_mtprtccp02", "rr_s_mtprtccp12", "rr_d_mtpdteexp",
                "rr_d_mtprtmat1", "rr_s_mtprtmcnv0", "rr_s_mtprtmcnv1", "rr_s_mtprtmfrp0", "rr_s_mtprtmfrp1",
                "rr_i_mtprtmmrg0", "rr_i_mtprtmmrg1", "rr_s_mtprtmrte0", "rr_s_mtprtmrte1", "rr_d_mtprtsd0",
                "rr_d_mtprtsd1", "rr_i_mtpstrike", "rr_s_mtpstrtgy", "rr_s_mtptrader", "rr_s_mstpstatus",
                "rr_s_mtrnfmly", "rr_s_mtrngrp", "rr_s_mdfusi", "rr_s_maction", "rr_d_mtpdteexp_2", "rr_t_mtimecmp_4",
                "rr_s_mtpcmlnat0", "rr_s_mtpcmlnat1", "rr_s_mtprtpr0", "rr_s_mtprtpr1", "rr_s_mtpbuy", "rr_i_mdfmarkid",
                "rr_d_mtprtmat0", "rr_d_field_48", "rr_s_mdfbilate", "rr_s_mdfexevenu", "rr_s_mdfuti", "rr_s_mgestor",
                "rr_s_mindicador", "rr_s_mskelet", "rr_s_mtpbrolbl0", "rr_s_mtrntype", "rr_s_mdfcpbroke",
                "rr_s_mdfcpbnfc", "rr_i_mdfmarkid_2", "rr_s_mdfconfpl", "rr_s_mtpcntrp", "rr_s_nominal1",
                "rr_s_nominal2", "rr_s_mtpcmnt0", "rr_s_mtpcmnt1", "rr_s_mtpcmnt2", "rr_s_mtpcmntxt0",
                "rr_i_mtpcmntxt1", "rr_s_mtpcmntxt2", "rr_s_amountupf", "rr_s_cashdelivery", "rr_s_mtprtmfrp0_2",
                "rr_s_mtprtmfrp1_2", "rr_s_capunit", "rr_i_quantity", "rr_s_frqqty", "rr_s_totqty", "rr_s_settle0",
                "rr_s_price", "rr_s_plinscur", "rr_s_priccurr", "rr_s_physical1", "rr_s_location1", "rr_s_physical2",
                "rr_s_location2", "rr_s_grade", "rr_s_brwcp", "rr_s_optstyle", "rr_s_brwpremium", "rr_s_hoursft",
                "rr_s_hourstzone", "rr_s_daysofweek", "rr_s_loadtype", "rr_s_marcafx", "rr_s_mic", "rr_s_flextype",
                "rr_s_settelement", "rr_i_ndf_mxpfwsett", "rr_s_settelementdate", "rr_s_mtpsptfwd", "rr_d_mtpipaydte",
                "rr_d_mtpdtecpn", "rr_s_mgroupris", "rr_s_protection", "rr_s_mcreditso", "rr_s_mseniority",
                "rr_b_negociada", "rr_d_mspotdfa", "rr_i_mnominal", "rr_d_mdelivery", "rr_s_mcnttypo", "rr_s_mtpprice",
                "rr_s_mtpipaycur", "rr_s_mtppcond", "rr_i_mtpiqty", "rr_s_mtpfxxgrp", "rr_s_mtpnotional",
                "rr_s_mpayoff", "rr_s_mdfreppar", "rr_s_mvevtcls", "rr_i_mtprtvlc02", "rr_i_mtprtvlc12",
                "rr_i_mtprtmgc02", "rr_i_mtprtmgc12", "rr_s_meqratio", "rr_s_mbreakclause", "rr_s_moptional",
                "rr_s_mexrstartd", "rr_s_mfrecuencia", "rr_s_mexrdelay", "rr_s_mexrgen", "rr_s_msubpderiv",
                "rr_s_mexrlength", "rr_s_mtpipay", "rr_s_mtpobartyp", "rr_s_mtpcancby", "rr_d_mtpdtefxgf",
                "rr_d_mtpdtefxgl", "rr_d_mtpipaydte_2", "rr_i_field_140", "rr_s_mlnpayout", "rr_s_mfloatingk",
                "rr_s_mrtmat0", "rr_s_mdfusinv", "rr_s_mdfaevtid", "rr_s_subyacente_ndice", "rr_s_tipo_subyacente",
                "rr_i_root_contract", "rr_s_buysell_protetionduco", "rr_s_isinsubyacente", "rr_s_executiontimestamp",
                "rr_s_codtradetagging", "i_boleta__requiere_diccionario_", "s_cuenta_de_firma__excel_", "d_a_la_fecha2",
                "s_identificador_del_ordenante", "s_id_contrato_cliente", "s_identificador_orden_vasp_espa_a",
                "s_identificador_orden_maxxtrader___pse", "s_identificador_ejecucion_maxxtrader___pse",
                "s_identificador_operacion_lp", "f_cantidad_ejecutada", "f_contravalor", "s_buy___sell",
                "s_divisas_operacion", "s_identificador_lp", "dt_tiempo_de_ejecuci_n_maxxtrader", "s_divisa_del_precio",
                "f_cantidad_negociada", "f_comision", "s_divisa_de_la_comision", "f_importe_total",
                "s_divisa_del_importe_total", "s_cantidad_a_vender", "s_divisa_de_venta", "f_cantidad_a_comprar",
                "s_divisa_de_compra", "s_estado_liquidacion_bo_pata_lp", "s_estado_liquidacion_bo_pata_vasp",
                "rr_s_mtimecmp_3", "rr_s_mtprtmat1", "rr_s_mtprtmat0", "i_boleta__necesita_diccionario_",
                "d_a_la_fecha_", "s_cuenta_de_firma", "f_monto", "s_monto_nocional_pag", "rl_d_asofdt", "rl_d_transac",
                "rl_t_trtime", "rl_i_tkt", "rl_s_bbid", "rl_i_amount", "rl_f_price", "rl_s_tblt", "rl_d_mtydate",
                "rl_d_stldate", "rl_s_counterpar", "rl_s_shortname", "rl_s_securitytype2", "rl_f_net_amount",
                "rl_s_crcy", "rl_s_long_description", "rl_s_external_order_identifier", "rl_s_trader",
                "rl_s_bb_unique_id", "rl_s_shrt_name", "rl_f_principal", "rr_i_nb", "rr_d_fcontratacion",
                "rr_s_callput", "rr_f_strike", "rr_f_nominal", "rr_f_titulos", "rr_f_lotsize", "rr_s_tipoproducto",
                "rr_s_tipoopcion", "rr_s_instrumento", "rr_d_fvencimiento", "rr_s_liquidacion", "rr_s_mercado",
                "rr_f_precio", "rr_s_camaracontrapartida", "rr_s_subyacente", "rr_s_divisapago", "rr_f_remaininglqty",
                "rr_s_clearerfeedest", "rr_t_mtimecmp", "rr_f_mtimecmp_3", "rr_f_mtprtccp02", "rr_f_mtprtccp12",
                "rr_f_mtprtmmrg0", "rr_f_mtprtmmrg1", "rr_i_mtprtmrte1", "rr_f_mtpstrike", "rr_f_quantity",
                "rr_f_totqty", "rr_f_price", "rr_f_brwpremium", "rr_f_mnominal", "rr_f_mtpiqty", "rr_s_mtprtvlc02",
                "rr_f_mtprtvlc12", "rr_f_mtprtmgc02", "rr_f_mtprtmgc12", "rr_f_mtpipay", "s_serviciocreador",
                "s_macroepi", "cf_d_fecha_ejecucion", "cf_d_fecha_valor", "s_fecha_valor_aux", "cf_s_fecha_valor",
                "s_clave_auxiliar", "d_mpaymentdate", "f_mflow", "rl_i_mtradenumber", "rl_s_mstrategy", "rl_s_mproduct",
                "rl_s_mcounterpart", "rl_s_mportfolio", "rl_s_mflowtype", "rl_s_mflowtypologies", "rl_d_mexpirydate",
                "rl_d_mvaluedate", "rl_d_mcalculationstartdate", "rl_d_mcalculationenddate", "rl_s_mnominal",
                "rl_s_mfixingdate", "rl_s_mindex", "rl_f_mrate", "rl_s_mmargin", "rl_d_mpaymentdate", "rl_f_mflow",
                "rl_s_mcurrency", "rl_s_msourcesystem", "rl_s_minternallink", "rl_d_mreportingdate",
                "rr_i_mtradenumber", "rr_s_mstrategy", "rr_s_mproduct", "rr_s_mcounterpart", "rr_s_mportfolio",
                "rr_s_mflowtype", "rr_s_mflowtypologies", "rr_d_mexpirydate", "rr_d_mvaluedate",
                "rr_d_mcalculationstartdate", "rr_d_mcalculationenddate", "rr_s_mnominal", "rr_s_mfixingdate",
                "rr_s_mindex", "rr_f_mrate", "rr_s_mmargin", "rr_d_mpaymentdate", "rr_f_mflow", "rr_s_mcurrency",
                "rr_s_sourcesystem", "rr_s_minternallink", "rr_d_mreportingdate", "s_clave_cruce", "rl_s_mdtpaycur0",
                "rl_d_mdtpaymnt0", "rl_f_mdtprmam0", "rl_s_mtpcntrp", "rl_f_mtpnominal", "rl_s_mdtflowtyp", "rl_s_mnb",
                "rl_s_m_bstrategy", "rr_s_mnb", "rr_s_mdtpaycur0", "rr_d_mdtpaymnt0", "rr_f_mdtprmam0",
                "rr_f_mtpnominal", "rr_s_mdtflowtyp", "rr_s_m_bstrategy", "f_contado", "f_vencido", "f_forward",
                "f_descuadres_hist_ricos", "rl_s_fecha", "rl_s_indicador_factor_amortizacion", "f_rate",
                "f_initial_amount", "f_termination_amount", "rr_s_contrapartida_calypso__bdi_",
                "rl_s_contrapartida_brokertec", "i_canonical_rdr", "s_entidad_particpante", "s_referencia_operacion",
                "s_cif", "rl_s_n_de_expediente", "rl_i_n_de_tramo", "rl_s_tramo", "rl_f_importe_dispuesto_bbva",
                "rl_f_disponible_agrupado_bbva", "rr_s_custodios", "s_nacional_internacional",
                "f_boposition_internal_total", "rl_s_book", "rr_s_borrowed", "f_triparty_fallido", "f_triparty_tomado",
                "f_backdated", "f_created", "f_failed", "f_man_choice", "f_man_validation", "f_total_transfer_report",
                "rr_s_status", "rl_s_agent", "rr_s_plaza", "s_numero_de_referencia", "s_codigo_de_oficina",
                "d_fecha_de_liquidacion", "rl_s_tipo_de_movimiento", "rl_s_entidad_participante", "rl_s_n_de_tramo",
                "s_instrumentocuadrestmx", "s_tipooperacion", "s_tipoopcion", "s_tipoproducto", "d_fvencimiento",
                "s_cuentaaltura", "d_fcontratacion", "f_titulos", "s_camaracontrapartida", "rl_i_nb",
                "rr_i_ubixinternaltradenumber", "s_dg", "d_fec_cont", "d_fec_valor", "s_div", "rl_s_sc", "rl_s_oper",
                "rl_s_descripcion_operacion", "rl_s_pfr", "rl_s_texto_movimiento", "rl_s_cuenta_origen", "rl_s_n_proc",
                "cf_f_saldo", "s_saldo", "cf_s_revisi_n_vencidos", "s_expediente_clan", "s_tramo", "s_nombre_de_tramo",
                "s_expediente_nacar", "s_producto_financiero", "f_l_mite", "rr_s_cdigo_contrapartida_cliente",
                "rl_s_cliente", "rr_s_rol_oficina", "s_criterio_roll_up", "f_movimiento", "s_fecha_de_movimiento",
                "cf_f_saldo_total", "s_transaction_type", "s_atributo", "s_roll_up_pt", "f_debe", "f_haber",
                "s_roll_up_market_inf_ref_dca", "s_trn___agrupacion_amiga", "s_ccv", "d_fecha_teorica_de_liquidacion",
                "s_cod_cruce", "s_codigo_operacion", "f_numero_de_titulos", "f_importe_efectivo",
                "cf_f_diferencia_efectivo_neto", "s_oficina_ccv", "s_tipo_de_activo", "rl_d_fecha_contrataci_n_amiga",
                "rr_d_fecha_contrataci_n_nscv", "rl_f_retencion_fiscal_amiga", "rr_f_retencion_fiscal_nscv",
                "rl_s_ajuste_contabilidad_amiga", "rr_s_ajuste_contabilidad_nscv", "cf_s_tipo_operacion",
                "rl_s_cod_servicio_creador", "rr_s_cod_servicio_creador", "rl_s_cod_banco_contable",
                "rr_s_cod_banco_contable", "rl_s_cod_sucursal", "rr_s_cod_sucursal", "rl_s_cod_contrapartida",
                "rr_s_cod_contrapartida", "rl_s_ubi", "rr_s_ubi", "rl_s_ccontable_desglose", "rr_s_ccontable_desglose",
                "rr_d_fecha_valor", "rl_s_producto_financiero_refundidor", "rr_s_producto_financiero_refundidor",
                "rl_s_asiento_contable", "rr_s_asiento_contable", "rl_s_apunte_contable", "rr_s_apunte_contable",
                "rl_s_apunte_secuencia", "rr_s_apunte_secuencia", "rl_s_banco_contrato", "rr_s_banco_contrato",
                "rl_s_oficina_contrato", "rr_s_oficina_contrato", "rl_s_contrapartida_contrato",
                "rr_s_contrapartida_contrato", "rl_s_cod_folio_contrato", "rr_s_cod_folio_contrato",
                "rl_s_complemento_contrato", "rr_s_complemento_contrato", "rl_s_texto_apunte", "rr_s_texto_apunte",
                "rl_s_indicador_regulador", "rr_s_indicador_regulador", "rl_s_identificador_mto",
                "rr_s_identificador_mto", "rl_s_clase_valor", "rr_s_clase_valor", "rr_s_operacion_nscv",
                "rl_s_debe_haber_amiga", "rl_f_importe__efectivo_", "rr_f_importe__efectivo_", "i_expediente",
                "d_field_6", "s_field_18", "s_field_21", "s_fecha_liquidaci_n", "f_cash_flow_amount",
                "f_importe_liquidaci_n", "rl_s_fecha_inicio_flujo", "rl_s_fecha_fin_flujo", "rl_s_fecha_sistema",
                "rl_s_fecha_fijaci_n", "rl_s_origen_front_office", "rr_s_origen_back_office", "rr_i_entidad",
                "rr_i_oficina", "rr_s_ric", "s_label", "s_instrument_pl_currency", "rl_s_family", "rl_s_group",
                "rl_s_type", "rl_s_n__operaci_n_murex", "rr_s_tipo_de_fondo", "s_plaza", "s_identificador_depo_loan",
                "rr_s_loan_codigo_subunidad", "s_branch_codealpha", "s_currency_code", "d_rollover_date",
                "d_last_rollover_date", "cf_d_fecha_proceso", "rl_s_depo_deallendingdl", "rl_s_depo_deal_type",
                "rr_s_loan_loan_type", "rl_s_depo_deal_subtype", "rr_s_loan_loan_subtype", "rl_s_depo_customer_name",
                "rr_s_loan_customer_name", "rl_s_depo_customer_number", "rr_s_loan_customer_number",
                "rl_d_depo_deal_date", "rr_d_loan_deal_date", "rl_d_depo_value_date", "rr_d_loan_value_date",
                "rl_d_depo_next_rollover_date", "rr_d_loan_rollover_date", "rl_f_depo_originalprincipal_amount",
                "rr_f_loan_amount", "rl_f_depo_ratespread", "rr_f_loan_ratespread", "rl_f_depo_spread",
                "rr_f_loan_margin", "rl_i_depo_interestcalculation_basic", "rr_i_loan_interestcalculation_basic",
                "rl_s_depo_numero_cliente", "rl_s_depo_deal_number", "rl_s_depo_front_officetransaction_id",
                "rr_f_loan_total_interests", "rr_s_loan_facility_ref", "rr_s_facility_facility_type",
                "rr_i_facility_average_life", "rr_i_loan_average_life", "s_nominal", "cf_f_diferencia_t_tulos",
                "s_account", "d_creation_date", "d_book_date", "s_narrative", "f_opening_balance", "f_closing_balance",
                "s_tipo_operacion", "rl_s_contrapartida__clan_", "s_titular", "rl_i_operacion__clan_",
                "rr_i_operacion__murex_", "rl_i_expediente__clan_", "rl_s_titular__clan_", "rl_s_tramo__clan_",
                "rr_s_name__murex_", "rl_d_settlement_date__clan_", "rr_s_settlement_date__murex_",
                "rl_s_entidad__clan_", "rl_s_estado__clan_", "cf_s_fecha_descuadre", "d_fecha_operaci_n",
                "d_fecha_valor_operaci_n", "cf_s_veh_culo", "s_c_digo_st", "cf_s_serie", "s_descripci_n_del_movimiento",
                "s_concepto_servicio_creador", "s_divisa_del_movimiento", "f_importe_movimiento",
                "cf_s_n_mero_de_operaci_n", "cf_s_identificador_de_la_liquidaci_n", "rl_i_servicio_creador",
                "s_saldo_disponible_posterior", "s_saldo_contable_posterior", "rl_s_nscv_code", "rl_s_nscv_code_2",
                "f_importe_movimiento_consulta", "s_trade_date_formateada", "rl_s_expediente__clan_",
                "s_codigo_de_busqueda", "s_agencia_partis", "s_nuestra_ref", "s_cont", "s_macc", "s_mascara",
                "s_dependiente", "s_codexpdelta", "s_codtramexp", "s_acontecimiento80", "f_saldocontable",
                "f_diferencia", "s_fechadesconciliacion", "s_conci", "s_productofinanciero", "rl_s_tipologa_miss",
                "rl_s_tipologa_descuadres", "rl_s_comentarios_delta", "rl_s_responsable_resolucin",
                "rl_s_fecha_de_entrada", "rl_s_fecha_prevista_resolucin", "rl_s_estado", "rl_s_prioridad",
                "rl_s_repetidos_contratos", "rl_s_aux", "rl_s_remedy", "rl_s_fcomprimiso", "cf_s_prueba",
                "rr_s_id_abaco", "rr_f_importe_liquidaci_n", "s_divisa_de_flujo", "rl_s_divisa_liquidaci_n__mx_",
                "s_fase", "s_pata", "rr_s_a", "s_cruce", "s_n_mero_orden", "s_c_digo", "f_saldo",
                "cf_f_saldo_total_abs", "s_operaci_n_fr", "f_tipo_de_cambio", "cf_f_saldo_total_contravalorado",
                "f_saldo_contravalorado", "s_ajustabilidad", "d_fecha_discrepancia", "d_fecha_de_liquidaci_n",
                "s_customer_number", "s_account_code", "s_account_sequence", "s_branch", "rl_d_posting_date",
                "rl_d_value_date", "s_loan_number", "s_referencia_banktrade", "s_seq_number", "s_voucher", "s_event",
                "rl_s_loan_customer_number", "rl_s_customer_name", "rl_f_account_balance", "rr_s_a__mercado_ubix",
                "s_contrato_teorico_altura", "s_clearer_broker", "s_divmercado", "s_divclearing", "rl_s_divejecucion",
                "rl_i_operacion", "rr_s_a__quantity", "cf_f_total_altura", "cf_f_total_ubix", "cf_f_diferencia_total",
                "cf_f_diferencia_mercado", "f_com_mercado", "cf_f_diferencia_ejecucion", "f_com_ejecucion",
                "cf_f_diferencia_clearing", "f_com_clearing", "rr_s_pexch", "rr_s_pfc", "rr_s_psymbl", "rr_i_pexpdt",
                "rr_s_pspred", "rr_s_psdsc1", "rr_f_ptpric", "rl_f_mercado", "rl_f_ejecucion", "rl_f_clearing",
                "s_plataforma", "s_sistema_fo", "s_id_mercado", "s_id_pse", "s_bloomberg__batch_id",
                "s_360t_parentreferencenumber", "f_tipo_cambio", "f_tipo_cambio_inv___plataformas_",
                "d_fecha_contratacion", "f_nominal_cobro_crv_eur", "f_nominal_pago_crv_eur", "rl_s_side", "s_criterio",
                "rr_s_cod_venue", "rr_s_aplicacion_origen", "rl_d_transaction_date", "rl_t_transaction_time",
                "rl_s_pata", "rl_s_producto", "rl_s_id_mercado_plataformas", "rr_s_id_front", "rr_s_desordid_id",
                "rr_s_id_front_star_b", "rr_s_desordid_star", "rr_s_desclioid_id_star", "rr_s_cod_venue_star",
                "s_sentido_de_la_operaci_n", "rr_f_current_nominal", "rr_f_principal_amount", "rr_i_trade_id",
                "rr_d_entered_date", "rr_s_tradestatus", "rl_s_m_tp_status2", "rl_d_m_tp_dtesys", "rl_f_m_brw_nom2",
                "rl_s_m_brw_nomu2", "cf_f_amount_crv_eur_murex", "cf_f_amount_crv_eur_calypso", "f_decalaje",
                "rl_s_importe_p_l", "rl_s_importe_multidivisa", "rl_s_importe_mto_m_1", "cf_s_dividendo",
                "f_importe_tolerancia", "rl_s_servicio_creador", "cf_s_pclosed", "rr_d_contractmaturity",
                "rl_d_maturity_date", "cf_f_prueba_strike", "s_referencia_cruce", "cf_f_suma_importe",
                "s_tipo_producto", "s_trade_id", "s_transfer_id", "s_servicio_creador", "s_texto_movimiento",
                "s_ind_regularizador", "cf_f_suma_importe_crv_eur", "cf_s_failed_transfer_id",
                "cf_s_failed_transfer_status", "s_ind_reg_n", "s_ind_reg_s", "cf_d_fecha_descuadre",
                "cf_s_unique_key_ubix", "cf_s_unique_key_dtcc", "s_external_ubix_code", "s_contract_type",
                "s_isin_producto", "s_isin_subyacente", "cf_f_pclosed", "s_venue", "cf_s_venue_check_2", "s_month",
                "s_year", "cf_s_psdsc1", "f_quantity_futuros", "f_quantity_opciones", "rl_i_quantity",
                "cf_s_gtr_validation_status", "cf_s_gtr_error_codes", "cf_s_gtr_error_descriptions_", "rl_s_trade_id",
                "rl_s_product_identification", "rr_s_contractcode", "rr_s_underlying",
                "rl_s_trade_party_transaction_id", "rl_s_contract_type", "rl_s_asset_class", "rl_s_collateralisation",
                "rl_s_underlying_identification", "rl_s_type_of_id_of_the_other_counterp",
                "rl_s_report_submitting_entity_id", "s_notional_crv_eur", "rr_f_closeprice",
                "rl_dt_reporting_timestamp", "rr_d_date", "rr_s_underlyingtype", "rr_i_position", "rr_f_pointvalue",
                "rr_s_exchange", "rr_s_contractreference", "rr_s_clearer", "s_referencia_de_cruce",
                "rl_d_fecha_contable", "rl_s_divisa", "cf_f_importe_crv_eur__left_side_",
                "cf_f_importe_crv_eur__right_side_", "rl_s_ind_regularizador", "s_c_digo_contrapartida",
                "s_nombre_contrapartida", "s_servicio_creador_rollup", "cf_s_emisor", "s_nuevo_venue",
                "rl_s_fecha_fijaci_n_tipo_de_cambio", "s_execution_timestamp", "s_pase_1___id_icelink",
                "s_pase_2_clave__nica", "f_payment_amount", "cf_s_mesa_murex", "rr_s_trader", "rl_s_block_trade_id",
                "rl_s_buyer_entity", "rl_s_group_id", "s_counterparty_2", "rl_s_custodio", "f_nominal__bony__aggr_",
                "f_nominal_euroclear__coll_", "f_nominal_clearstream__avai_", "s_custodio_match", "cf_s_alias",
                "f_nominal__bony__aggr__crv_eur", "f_nominal_euroclear__coll__crv_eur",
                "f_nominal_clearstream_avai_crv_eur", "f_importe_movimiento_crv_eur", "rl_d_as_of_date",
                "rl_i_ticket_id", "rl_s_price", "rl_s_counterparty", "rl_s_usi", "rl_s_uti", "rl_s_facc_short_name",
                "rl_s_restructuring_type", "rl_s_cds_flat", "rl_d_cds_cash__settlement_", "rl_s_cds_reference",
                "rl_s_seniority__debt_type_", "rl_d_effective", "rl_i_pay_notional", "rl_s_received_currency",
                "rl_i_swap_spread", "rl_i_receive_notional", "rl_s_swap_type", "rl_s_cds_irs_status", "d_as_of_date",
                "s_usi", "i_quantity", "s_pay_notional", "s_received_currency", "rl_f_cds_flat", "rr_s_mtimecmp_2",
                "rr_s_mtpaccsct", "rr_s_mdfmarkid", "rr_s_mtpcmntxt1", "rr_f_mtpprice", "rr_f_mtprtvlc02",
                "rr_s_root_contract", "s_m_h", "rl_d_fixing_date", "f_pay_notional", "rr_f_mtpnotional",
                "rr_f_nominal1", "rr_f_nominal2", "d_transaction_date", "f_amount__a_revisar_", "s_uti__usi____",
                "d_effective", "rl_s_unique_swap_identifier_for_trade", "rl_s_field_11", "d_fecha_de_transacci_n",
                "s_short_name___instrumento", "s_cuenta_altura", "s_custodios", "cf_f_transfer_report_total",
                "f_boposition_int_total_crv_eur", "rl_s_id_toms", "rr_s_id_murex", "s_isin_match", "rr_f_scf",
                "rl_s_codigo_st_mx3", "rr_s_codigo_st_star", "s_dealogic_group", "rr_d_fecha_de_emision",
                "rl_s_status_st", "rl_s_mtpnomcur", "f_importe_crv_eur", "s_scf_crv_eur", "rr_d_fecha_de_alta",
                "rr_d_fecha_contratacin", "rr_d_fecha_de_vencimiento", "f_nominal__a_revisar_", "s_trader___portfolio",
                "dt_transac_time", "s_tiempo_de_ejecuci_n_maxxtrader", "s_transac_time", "rl_i_swap_sp",
                "rl_s_security", "rl_s_full_name", "rl_f_swap_sprea", "rl_s_t_login", "f_swap_spread", "rl_d_eod",
                "rl_s_aplicacionorigen", "rl_s_codtipo", "rl_s_codpaisoalf", "rl_s_codentalfa", "rl_i_codoficina",
                "rl_s_codidcontra", "rl_s_folio", "rl_s_codpgcontr", "rl_s_codrdr", "rl_d_fecvalorcontrato",
                "rl_d_feccontablemov", "rl_s_estmov", "rl_s_tipomov", "rl_s_idmovircm", "rl_s_paisres",
                "rl_s_codliquidacion", "rl_s_metliquidacion", "rl_d_fecentmr", "rl_s_codsitudeu", "rl_d_fecfecproce",
                "rl_d_fecultmovi", "rl_s_qnunummovi", "rl_s_codqnudocmov", "rl_d_fecfmovimmov", "rl_d_fecfvalormov",
                "rl_s_codconcdeumov", "rl_s_codacciodeumov", "rl_s_codcaracdeumov", "rl_s_codoperdeumov",
                "rl_s_codmedpagmov", "rl_f_impimpdeudamov", "rr_s_tipo_de_registro", "rr_s_pa_s", "rr_s_entidad",
                "rr_s_iuc", "rr_s_n_mero_de_cuota", "rr_d_fecha_operaci_n", "rr_s_concepto", "rr_s_acci_n",
                "rr_s_caracter_stica", "rr_s_operaci_n", "rr_s_tipo_de_operaci_n",
                "rr_f_importe_del_movimiento_en_la_divisa_del_contrato", "rr_s_identificador__nico_de_movimiento_ircm",
                "s_clave_economica", "s_rate", "s_end_date", "s_buysell", "rr_s_portfolio_desk",
                "rl_s_trade_number_eurex", "rr_s_trade_id_calypso_triparty", "rr_d_entered_short_date",
                "rr_s_sales_person", "f_nominial_crv_eur", "f_termination_amount_crv_eur", "f_initial_amount_crv_eur",
                "s_desk", "f_nominal_1", "f_delivertocompid", "f_nominal_2", "rl_i_id_toms", "cf_f_calculated_result_1",
                "rr_s_currency_to", "rr_s_liquidity_status_lp", "rr_s_liquidity_status_vasp", "rr_s_tradeid",
                "s_360t_clave_cruce", "s_location", "rl_s_counterparty_trader_name", "rl_s_trader_name",
                "rl_i_trader_uuid", "rl_s_trade_report_id", "d_payment_date", "rl_s_class", "rl_s_instrument",
                "rl_s_counterpary_deal_code", "rl_s_currency", "rl_s_currency_2", "rl_s_callput_currency",
                "rl_s_n_mero_operaci_n_star", "rr_s_n_mero_operaci_n_murex", "d_fecha_alta", "s_fecha_contrataci_n",
                "s_fuente_de_fijaci_n", "s_aplicaci_n_origen", "s_n__operaci_n_aplicaci_n_origen",
                "f_nominal_cobro_crv_usd", "f_nominal_pago_crv_usd", "rl_s_hora_cierre_mercado",
                "rl_s_fecha_liberacion", "rr_d_fecha_ultima_lib_operaci_n", "rr_d_timestamp", "rr_t_hora_inserci_n",
                "rl_s_lifecycle_status", "s_traiana_id", "s_p3___pse", "s_mx_contract_id", "s_star_id", "rr_s_murex_id",
                "s_p1___traiana_id", "s_p2___traiana_id", "s_trade_date_traiana__date_", "d_value_date__date_",
                "rl_s_direction", "cf_f_nominal_cobro_crv_traiana", "cf_f_nominal_cobro_crv_mx_star",
                "cf_f_nominal_pago_crv_traiana", "cf_f_nominal_pago_crv_mx_star", "rl_s_entering_party_ref",
                "s_maturitytype", "s_mtpdteexp", "s_mtpdtetrn", "s_multiisin", "s_mcnttypo", "s_family",
                "rr_s_tradekeywordsimpletransfertype", "d_mtpdteexp", "dt_mtpdtetrn", "s_cash_flow", "d_star_date",
                "d_mtpdtetrn", "s_id_murex", "rr_s_id_calypso", "f_fixed_rate", "s_security_currency", "s_pass_through",
                "s_cash_frequency", "s_index_name", "s_day_count", "s_maturity_type", "s_subtype", "i_trade_id",
                "cf_f_titulos_diferencia", "f_lot_size", "cf_d_fecha_ejecuci_n_", "s_id_operacion", "f_mtm",
                "s_origen_front", "s_error_log", "rl_s_rtcedealid", "cf_s_node_type__algorithmics", "rl_s_positionid",
                "rl_s_instrumentid", "rl_s_internalbranch", "rl_s_internallegalentity", "rl_s_branch",
                "rl_s_legalentity", "rl_s_masteragreement", "rl_s_collateralagreement", "rl_s_producttype",
                "rl_s_jurisdiction", "rl_s_activitytype", "rr_s_codcurpl", "rr_s_codnumoperfront",
                "rr_s_codcounterpart", "rr_s_xtiisinternal", "rr_s_codportfolio", "rr_s_codfamily", "rr_s_codgrupo",
                "rr_s_codtipoperacion", "rr_d_fecexpirydate", "rr_s_codstatus", "rr_d_fecinitialpay",
                "rr_s_codstrument", "rr_s_codentity", "rr_f_impnonfmv", "rr_f_imptipocambio", "rr_f_impmvcontraeur",
                "rr_s_codaplicacionfront", "cf_s_obtiene_mtm", "cf_s_duplicada", "cf_s_casu_stica", "cf_s_bofye",
                "cf_s_excluidas", "cf_i_portfolios_excluidos_del_rc", "cf_s_operativa_wildcard", "cf_s_control_mtm",
                "cf_s_contrapartida_interna", "cf_s_descripci_n_de_reproceso", "s_cantidad_eur", "rl_s_clordid",
                "f_cantidad_a_vender", "f_cantidad_eur", "s_cash_flow_days", "s_period", "s_index",
                "cf_f_mtm_difference__", "rr_s_cod_tipoproducto", "cf_d_fecha_de_la_posici_n", "rr_s_sentido",
                "rr_s_mesa", "rr_s_id_star", "rl_s_minstrument", "rr_d_fecha_emisi_n", "s_mandato_volcker",
                "rr_s_idrequestedportfoliosystem", "s_geograf_a", "s_tipo_de_portfolio", "rr_s_idgmruperimetermrrisk",
                "rr_s_idwfstatus", "rl_s_nodo1", "rl_s_nodo2", "rl_s_nodo3", "rl_s_nodo4", "rl_s_nodo5", "rl_s_nodo6",
                "rl_s_nodo7", "rl_s_nodo8", "rl_s_nodo9", "rl_s_nodo10", "rl_s_nodo11", "rl_s_nodo12", "rl_s_nodo13",
                "cf_f_total_clearer", "rr_f_comision_ejecucion", "rr_f_comision_mercado", "rr_f_comision_clearing",
                "rl_s_m_accnt_scf", "rr_i_id_star", "f_posicion_crv_eur", "rl_s_m_tp_cntrpid", "rr_s_libro",
                "s_auxiliar_de_libro_de_duplicidad", "cf_f_valor_absoluto_mx", "cf_f_valor_absoluto_st",
                "f_position_crv_eur", "f_position_sin_factor", "cf_f_position_crv_eur_diferencia", "s_clave__nica_mx",
                "s_clave__nica_st", "s_portfolio_tunidad_mx", "rr_s_portfolio_mx", "rr_s_portfolio_st", "f_position_mx",
                "f_position_st", "f_position_sin_factor_mx", "f_position_sin_factor_st", "s_mesa_mx", "s_mesa_st",
                "rl_s_alta_dm_mx", "rl_s_alta_dm_st", "rl_s_trading_mx", "rl_s_security_identifier_flag",
                "rl_s_trading_st", "s_isin_mx", "s_isin_st", "s_portfolio_traducido", "rl_s_trade_name_procesado",
                "rr_f_sumavqty", "rr_s_mtpnomcur", "cf_f_position_mx_crv_eur_toms", "cf_f_position_mx_crv_eur_st_mx",
                "cf_f_position_st_crv_eur_toms", "cf_f_position_st_crv_eur_st_mx", "f_importe_apunte",
                "s_divisa_operacion", "s_contract_id", "s_c_digo_estrategia", "cf_f_amount_crv_eur_murex_star",
                "cf_f_amount_crv_eur_jbpm", "rl_f_far_rate", "rl_s_value_date", "rl_d_value_date__date_",
                "rl_s_far_value_date", "rl_d_far_value_date__date_", "rr_s_counterparty", "rr_s_secfullname",
                "rr_s_seccode", "rr_s_nominalcurr", "s_symbol", "s_company", "s_company_2", "i_lotsz", "i_shortlots",
                "i_longlots", "i_lots", "s_counterparty_name", "i_amount", "s_counterparty_symbol", "s_expediente",
                "rl_s_colateral", "rl_s_descripci_n_contrapartida", "cf_s_calculated_result_1", "s_enlace_interno",
                "s_cantidad", "s_tradeid", "s_contractid", "rl_s_tipo_flujo", "rl_s_subtipo_flujo",
                "rl_d_fecha_inicio_flujo", "rl_d_fecha_fin_flujo", "rl_f_capital_restante", "rl_f_tipo_deposito",
                "rr_s_modulo_origen", "rr_d_fecha_contratacion", "rr_s_signo", "rr_f_tipo_cambio", "rr_s_comentario",
                "s_divisa_compra", "s_divisa_venta", "f_cantidad_compra", "f_cantidad_venta", "rl_f_cantidad",
                "s_compra_venta", "cf_s_match", "rr_s_name", "rr_s_product_acvar", "rl_s_codfamily", "rl_s_codgrupo",
                "cf_f_cuadre_mtm", "rl_s_codtipoproducto", "s_cantidad_compra", "s_cantidad_venta",
                "cf_s_comentario_hist_rico", "cf_s_estado_en_pro_", "f_principal_crv", "rl_s_trader_id",
                "f_notional_crv", "s_regla_uti", "rl_s_trn_type", "rl_s_trn_grp", "rl_s_tradeid_loan",
                "rr_s_tradeid_fx", "rl_s_contractid_loan", "rr_s_contractid_fx", "d_settle_date", "f_repo_rate",
                "s_principal", "rl_s_b_s", "rl_s_trade_date", "rl_d_settle_date", "rl_s_maturity_structure",
                "rl_s_maturity_date", "rl_f_repo_rate", "rl_s_benchmark", "rl_s_calloption", "rl_s_nominal",
                "rl_s_principal", "rl_f_haircut", "rl_s_index_type", "rr_s_counterpartyfull_name", "rr_s_sub_type",
                "rr_s_reporeverse", "rr_s_actiontypeconf", "rr_d_repo_start_date", "rr_d_repo_end_date",
                "rr_s_security_currency", "rr_f_efecida", "rr_f_efecvuelta", "rr_s_repo_interest_type",
                "rr_f_cash_fixed_rate_current", "rr_s_security_currency_2", "rr_f_repo_underlying_nominal",
                "rr_f_dirty_price", "rr_f_repo_underlying_nominal_2", "rr_i_executionvenue", "rr_s_idlevel1",
                "rr_s_idlevel2", "rr_f_haircut_value", "rr_s_ampjustification", "rr_s_counterpartyattributebdi",
                "rr_s_sftrmic", "rr_f_trade_id", "rr_f_execution_venue", "s_roll_up_altura", "s_check_uti",
                "cf_f_price___quantity_toms", "f_principal_dashb", "f_principal_dash", "cf_f_principal_dashb_crv_toms",
                "cf_f_principal_dashb_crv_murex3", "f_prueba", "rl_s_trn_family", "d_effective_date",
                "s_test_facc_short_name", "rr_s_type",
                "rl_s_aggregation_attr_producttypealgorithmics_primaryassetclass",
                "rl_s_aggregation_attr_producttypealgorithmics_producttype", "s_tipology", "rr_f_nominal_div",
                "rr_f_efectivo_ida", "rr_f_efectivo_vuelta", "s_haircut", "rr_s_cash_rate_index_name",
                "f_resultado_sigma__comparable_rof", "s_pv_discount", "s_numfront_tratado_", "s_maturity_structure",
                "rr_s_fixed_float", "d_reset_date", "f_float_rate", "s_swap_spread", "s_proyecto", "s_vintage",
                "s_registro_match", "s_tipo_cuenta", "s_subaccount", "rr_s_registro", "f_period", "s_id_plataforma",
                "rl_d_as_of_dt", "d_trade_date_2", "rr_s_producto_acvar", "rl_s_familia", "rl_s_grupo",
                "cf_f_cuadre_mtm____", "dt_fecha_ejecucion", "rl_s_codaplicacionfront", "rl_s_codnumoperfront",
                "cf_s_algo_nodo", "s_algo_nodo", "s_alias", "s_asset", "f_availableamount", "f_totalamount",
                "dt_updatetimestamp", "rl_s_address", "rr_s_gfdefinitiondesc", "rr_s_gfvirtassetsvcprvdgasaliasname",
                "rr_s_gfvirtualassetservprvdaccid", "rr_s_gfcustodyzoneid", "rr_f_gfblockchainaddropernblockamount",
                "rr_f_gfblockchainaddrquarantinebamount", "rr_f_gfblockchainaddrnonopernblckamount",
                "rr_f_gfvirtassvcprvdaccttoteuramount", "rr_f_gfviasssvcpractousdamount", "rr_dt_gfauditdate",
                "rr_s_gfuserauditid", "s_transactionhash", "s_operationscope", "s_operationdirection",
                "s_senderaddress", "s_receiveraddress", "s_network", "f_operationfee", "s_creationtimstamp",
                "s_vaspsender", "s_vaspreceiver", "s_referencenumber", "s_feestrategy", "s_operationstatus",
                "rr_s_gfliquidityproviderreceiverid", "rr_s_gfliquidityprovidersenderid",
                "rr_s_gfblockchainoperationdesc", "rr_s_gfmanualinsertind1type", "cf_f_diferencia_efectivo",
                "rr_s_product_subtype", "s_updatetimestamp", "rl_dt_creationtimstamp", "rr_s_gfreconciledresultindtype",
                "rl_s_tiplogy", "i_posici_n_calculada", "rr_i_en_vuelo", "rr_i_saldo", "rr_d_fecha", "d_fixing_date",
                "s_activo", "f_posicion_disponible", "f_posicion_total", "s_fecha_notificacion_insercion",
                "s_hash_de_la_transaccion", "s_scope", "s_direccion_de_la_operacion", "s_direccion_del_emisor",
                "s_direccion_del_receptor", "s_red", "s_alias_emisor", "s_alias_receptor",
                "s_referencia_de_la_transaccion", "s_tipo_de_comision", "s_estado_operacion", "rl_s_reset_date",
                "rl_d_reset_date", "rl_s_categoria", "s_clave_busqueda", "rl_s_destexto", "d_fecha_movimiento",
                "rl_s_regulador", "rl_s_saldocruce", "rl_s_saldocuenta", "rl_s_procedencia", "s_bdi_contrapartida",
                "d_fecha_de_contrataci_n", "f_pstnqty", "rl_dt_rptdt", "rl_d_busdt", "rl_s_rptent_lei",
                "rl_s_rptent_national_id_othr_id", "rl_s_rptent_national_id_othr_schme_nm_cd",
                "rl_s_rptent_national_id_othr_schme_nm_prtr", "rl_s_rptentmemberid", "rl_s_pstnacct",
                "rl_s_pstnhldr_lei", "rl_s_pstnhldr_nationalid_othr_id", "rl_s_pstnhldr_nationalid_othr_schmenm_cd",
                "rl_s_pstnhldr_nationalid_othr_schmenm_prtr", "rl_s_pstinhldrcategory", "rl_s_pstinhldrcntcteml",
                "rl_s_parentpstinhldrcntcteml", "rl_b_pstinhldrisidpdtind", "rl_s_prntent_lei",
                "rl_s_prntent_nationalid_othr_id", "rl_s_prntent_nationalid_othr_schmenm_cd",
                "rl_s_prntent_nationalid_othr_schmenm_prtry", "rl_s_venprodcde", "rl_s_trdngvenid", "rl_s_pstntyp",
                "rl_s_pstnmtrty", "rl_i_pstnqty", "rl_s_pstnqtyuom", "rl_s_pstnqtyuomdesc", "rl_f_deltapstnqty",
                "rl_b_riskrdcind", "rl_s_clientdata_isnoninvestfirm", "rl_s_clientdata_ishedgingexempt",
                "rl_s_clientdata_obligationtoprovideliquidity", "s_origin", "f_amount_2", "f_amount_3",
                "f_amount_ird_opt_otc", "f_amount_edq_opt", "s_divisa_1", "s_divisa_2", "s_trade_currency",
                "s_tipo_de_ejercicio", "s_tipo_de_liquidaci_n", "s_put_call", "s_estrategy", "f_amount_crv_eur",
                "f_amount_2_crv_eur", "f_amount_edq_opt_crv_eur", "f_amount_ird_opt_otc_crv_eur", "rr_s_mnb_murex_id",
                "rl_s_harmony_id", "s_clave_unica", "d_expiry_date", "s_trade_date_traiana", "s_counter_party",
                "f_quantity1", "f_quantity1_crv", "f_quantity2", "f_quantity2_crv", "rl_dt_creation_time",
                "cf_s_star_account", "rl_s_pb_code_sent_to_harmony", "rl_s_client_code_sent_to_harmony",
                "rl_f_premium_amount", "rl_s_premium_ccy", "rl_f_payout_amount", "f_nominal_div", "s_tipologia_mercado",
                "s_codigo_producto", "s_clasificacion_ajuste", "s_cod_apl_origen", "s_oficina_unidad", "s_oficina_cpty",
                "s_tipo_procedencia", "s_tipo_contrato", "i_marca_valora", "s_cartera_mes_actual",
                "s_cartera_mes_anterior", "s_producto_gestion", "s_clasificacion_cuenta", "s_serv_creador",
                "s_concepto_cg_folio", "s_tipo_boco", "rl_s_pfolio", "f_nominal_", "s_cartera_contable",
                "f_dc4c_pl_dif_tipo_cambio_cajas_eur", "f_dc4v_pl_dif_tipo_cambio_valoracion_eur", "s_macro_epigrafe",
                "s_oficiona", "cf_f_importe", "cf_d_fecha_cierre", "s_cod_jerarquico", "cf_f_importe_divisa",
                "s_clase_asiento", "s_codigo_apunte", "s_centro_coste", "s_ref_cruce", "s_centro_gasto",
                "cf_d_fecha_modificacion", "cf_t_hora_modificacion", "s_importe_aux", "s_importe_divisa_aux",
                "d_fecha_modif_aux", "s_hora_modif_aux", "s_serv_creador_2", "s_marca_macro_coberturas", "i_dc10_aux",
                "rl_f_nominalvivo", "rl_d_fechavencimientocaratulas", "rr_s_agrupa", "rr_s_undcd", "rl_s_tipcontrato",
                "rl_s_clasificacioncuenta", "rr_s_serviciocreador", "rl_s_isinligadoabonos", "rl_s_list_mode",
                "f_nominal_cc", "f_nominal_em", "s_security_currency_em_cc", "f_quantity_em_cc", "d_end_date_em",
                "f_dirty_price_em_cc", "f_haircut_em_cc", "rl_f_clean_price", "s_isin___instrumento",
                "rl_s_estado_emision", "f_de2_ajustes_masivo_aux", "s_instrumento_ubix", "s_comentario_pencru_2",
                "rr_s_estado_emision", "cf_dt_fecha_ejecucion_calculated", "f_resultado_sigma_perimetro_publicable_2",
                "s_eex_isin", "f_position_quantity", "rl_f_amount", "rl_f_amountpaid", "rl_f_amounttobepaid",
                "rr_d_fec__cont", "rr_d_fec__ult", "rr_s_saldo__", "rr_s_dif_saldo", "rl_s_tradeid", "rl_s_traderef",
                "rl_d_tradedate", "rl_d_expiredate", "s_primary_asset_class", "rr_f_clean_price", "rl_d_system_date",
                "s_indicador_interna_externa", "f_nominal_vs_42", "rl_s_field_61___lot_size",
                "rl_s_libro_duplicidad___ctrp", "rr_s_campo_observaciones", "cf_s_duplicidad_de_star", "rr_s_usuario",
                "rr_s_grupo_producto", "rr_s_producto", "cf_f_nominal_crv_eur_mx", "cf_f_nominal_crv_eur_star",
                "rl_s_field_66", "rl_s_cusip", "rl_dt_updatetimestamp", "f_amounttobepaid", "s_mclient", "f_nominal1",
                "s_divisa1", "f_nominal2", "s_divisa2", "s_msource", "d_tradedate", "rl_s_numerooperacion",
                "rl_s_typology", "rl_i_strike", "rl_f_nominal1", "rl_s_divisa1", "rl_f_nominal2", "rl_s_divisa2",
                "rl_s_msource", "rl_s_mevtref", "rl_i_version", "rl_s_tradeorigin", "rl_d_insertdate",
                "rl_d_tradeexpiry", "rl_i_franquicia", "rl_i_franquiciacva", "rl_i_cva", "rl_i_dva", "rl_s_gestor",
                "rl_s_nfcfx", "rl_s_nif", "rl_s_iddifusion", "rl_s_buysell", "rl_s_lowerbound", "rl_s_upperbound",
                "rl_s_notional", "rl_s_rootcontract", "rl_i_mcreator", "rl_s_mplkey1", "rl_s_tipclient", "rl_s_mclient",
                "rl_s_mpais", "d_tradeexpiry", "rl_f_strike", "s_familia", "s_grupo", "s_typology", "s_mk",
                "f_tradeexpiry_num", "f_rate_2", "s_fecha_inicio", "rl_s_tipo_de_inter_s",
                "rl_s_primer_tipo_de_inter_s", "rl_s_spread", "rl_s_expediente", "rl_s_campo_observaciones",
                "rl_s_indicador_operaci_n_madre", "rl_s_titular", "rl_s_sentido", "rl_s_plaza", "s_tipclient",
                "i_buysell_logica", "rl_f_impmtm", "rr_s_folio", "s_evento", "s_numerooperacion", "rr_s_mevtref",
                "rr_i_version", "rr_s_tradeorigin", "rr_d_insertdate", "rr_i_franquicia", "rr_i_franquiciacva",
                "rr_i_cva", "rr_i_dva", "rr_s_gestor", "rr_s_nfcfx", "rr_s_nif", "rr_s_iddifusion", "rr_s_lowerbound",
                "rr_s_upperbound", "rr_s_notional", "rr_s_rootcontract", "rr_i_mcreator", "rr_s_mplkey1", "rr_s_mpais",
                "f_principal_crv_eur", "rr_s_loan_loan_number", "rr_s_facility_average_life", "rr_s_loan_average_life",
                "d_depo_maturity_date", "f_tipo", "rl_s_facility_facility_typeindicator",
                "rl_s_facility_revolving_creditindicat", "rr_s_loan_spread_adj", "rr_s_loan_convention",
                "rr_f_loan_spr_adj", "rl_s_fechavalormes", "rl_i_plazo", "rr_s_fechavalormes", "rr_i_plazo",
                "rr_s_tramo", "f_all_in_price", "cf_s_mesa", "s_relaci_n", "rl_s_rerate", "rr_i_folio",
                "s_n__operaci_n_front_office", "s_onholdccp", "cf_f_importe_crv_eur__p_", "cf_f_importe_crv_eur__n_",
                "cf_s_lado_fc", "cf_s_lado_fv", "cf_d_fecha_comparaci_n", "cf_f_difrencia_crv_abs", "s_codaplorigen",
                "s_productogestion", "s_codigoproducto", "s_conceptocgfolio", "s_tipoprocedencia", "s_tipocontrato",
                "s_c_digo_neteo", "cf_d_fecha_comparacion", "rl_s_book_toms_glmx", "cf_dt_hora_inicio", "rl_s_cartera",
                "rr_s_numfront", "rr_s_marcavalora", "rl_s_marcavalora", "rr_s_marcamacrocobertura",
                "rl_s_marcamacrocobertura", "s_tipologiamercado", "rl_s_filler1", "rl_s_filler2", "rr_s_filler1",
                "rr_s_filler2", "cf_s_clasificacion_ajuste", "rr_s_tipo", "s_fechavencimiento", "s_carteramesactual",
                "s_carteramesanterior", "s_marcamacrocoberturas", "s_fechavencimientocaratulas", "s_nominalvivo",
                "d_fechavencimientocaratulas", "f_nominalvivo", "i_cartera", "s_id___rerate", "rl_f_dc21ajustesdegrmu",
                "rl_f_dc22asimetria", "cf_s_calculated_result_2", "s_fechavalor", "rr_d_fecha_inicio_renovaci_n",
                "rr_d_fecha_fin_renovaci_n", "rr_d_fecha_primera_renovaci_n", "rr_d_fecha__ltima_renovaci_n", "rr_s_nb",
                "d_fechavalor", "f_nominal_em_crv_eur", "rl_s_origen_front", "cf_s_marca_publicable",
                "cf_s_marca_comparable", "d_fechavencimiento", "f_resultadocontablepublicado",
                "f_resultadosigmaperimetropublicable", "s_divisa_de_entrada", "s_divisa_de_salida", "s_n__murex",
                "f_importe_divisa_de_entrada", "f_importe_divisa_de_salida", "f_import_divisa_de_entrada_crv_eur",
                "f_import_divisa_de_salida_crv_eur", "f_importe_divisa_de_entrada_crv_eur",
                "f_importe_divisa_de_salida_crv_eur", "rr_s_id_midas", "rr_s_cliente_corporativo", "rr_s_manual",
                "rl_s_id_plataforma", "s_id_plataforma_2", "rr_s_execution_venue", "rl_i_tradeno",
                "s_origen_plataforma", "cf_i_finsid", "cf_s_finsid", "s_cantidad_negociada", "rr_s_orderqty",
                "rr_s_lastpx", "rl_s_orderqty", "rl_s_field_1", "rl_s_field_2", "rl_s_field_3", "rl_s_field_4",
                "rl_s_field_5", "rl_s_field_6", "rl_s_field_7", "rl_f_field_8", "rl_s_field_9", "rl_d_field_11",
                "rl_d_field_12", "rl_f_field_13", "rl_f_field_14", "rl_s_field_15", "rl_s_field_16", "rl_i_field_17",
                "rl_s_field_18", "rl_s_field_19", "rl_f_field_20", "rl_s_field_21", "rl_d_field_22", "rl_i_field_23",
                "rl_f_field_24", "rl_f_field_25", "rl_f_field_27", "rl_f_field_28", "rl_f_field_29", "rl_s_field_31",
                "rl_s_field_32", "rl_s_field_34", "rl_s_field_35", "rl_s_field_36", "rl_f_field_37", "rl_s_field_38",
                "rl_s_field_39", "rl_f_field_40", "rl_f_field_41", "rl_d_field_42", "rl_d_field_43", "rl_d_field_44",
                "rl_s_field_45", "rl_s_field_46", "rl_d_field_47", "rl_s_field_48", "rl_s_field_49", "rl_f_field_50",
                "rl_s_field_51", "rl_i_field_52", "rl_i_field_53", "rl_s_field_54", "rl_s_field_55", "rl_s_field_56",
                "rl_s_field_57", "rl_s_field_58", "rl_s_field_59", "rl_f_field_61", "rl_s_field_62", "rl_s_field_63",
                "rr_s_tipo_de_condiciones_de_inter_s", "rr_s_importe", "rr_s_importe_divisa_base",
                "rr_s_importe_divisa_contable", "rr_s_saldo_vivo_divisa_base", "rr_s_saldov_vivo_divisa_contable",
                "rr_d_fecha__ltima_amortizaci_n", "rr_d_fecha_pr_xima_amortizaci_n", "rr_s_importe_euros",
                "rr_s_importe_global", "rr_s_importe_global_divisa_base", "rr_s_importe_global_divisa_contable",
                "rr_s_importe_global_euros", "rr_s_importe_global_cuota_final", "rr_s_importe_global_cuota_final_divis",
                "rr_s_importe_global_cuota_final_div_2", "rr_s_importe_global_cuota_final_eur",
                "rr_s_importe_cuota_final_divisa_base", "rr_s_importe_cuota_final_divisa_conta",
                "rr_s_importe_cuota_final_eur", "rr_s_saldo_vivo_euros", "rr_s_saldo_vivo_global",
                "rr_s_saldo_vivo_global_divisa_base", "rr_s_saldov_vivo_global_divisa_contab",
                "rr_s_saldo_vivo_global_eur", "rr_s_mtm", "s_field_6", "s_fecha_inicio_2", "s_fecha_vencimiento_2",
                "s_field_38", "d_maturitydate", "s_fechafijacion", "s_fechacalculo", "s_fechafijacion_1",
                "d_firstaccrualdate", "s_isrealbond", "f_coupon", "s_issuedate", "s_firstaccrualdate", "s_issuercode",
                "s_issuedamount", "s_outstanding", "s_initunitnominal", "s_liqpreferencecd", "s_bondlegbasis",
                "s_compoundfrequency", "s_compoundmethod", "s_fltlockoutdays", "d_fechacalculo", "s_porcentaje",
                "f_isrealbond", "rl_s_accounting_section", "s_maturitydate", "s_nominal_pendiente_de_amortizar",
                "s_seniority_liq_preference", "s_nominal_iniicial", "s_base_calculo", "s_coupon", "s_firstcoupondate",
                "s_finalcoupondate", "s_meidtipo", "s_liqholidaytreatm", "s_inflationind", "s_calendar", "s_iscallable",
                "rr_f_productcodecurrentnotional", "i_dc20_operativa_primary_opv_aux", "f_importe_ajust",
                "s_divisa_ajus", "s_descripci_n_contrapartida", "s_c_digo_asociaci_n", "cf_s_tipolog_a_flujo",
                "rr_s_tipologia", "rr_s_tc", "rr_s_cod_indiref3", "rr_s_el", "rr_s_cntabaco", "rl_s_plazo",
                "cf_f_importe_del_flujo_front_crv_eur", "cf_f_importe_del_flujo_abaco_crv_eur",
                "cf_f_diferencia_importe_del_flujo_crv_eur", "s_emisor", "s_face_value", "s_fecha_emision",
                "s_fecha_inicio_devengo", "s_periodicidad_del_cupon", "s_compound_method", "s_reset_lockout",
                "s_first_coupon_date", "s_last_coupon_date", "s_fix_to_float_indicador", "s_callable",
                "s_tratamiento_de_festivos_e_liq__fija_y_calculada", "s_inflation_indicador", "s_calendario",
                "s_covered", "s_securitization", "s_spread", "s_call_dates", "s_resetdays", "rl_s_referenceindex",
                "rr_s_genindex", "rr_s_notional_index", "rr_s_notional_index_factor", "rr_s_notional_index_tenor",
                "rr_s_flipper_coupon", "rl_s_importe_ajustabilidad", "s_fecha_fin", "s_nominal_inicial", "rr_i_month",
                "rr_i_year", "rr_s_jpmaccount", "rr_s_indicadordecalculodecomisiones", "rr_s_tradeprice",
                "rr_s_optionpremium", "rr_s_executingbroker", "rr_s_executionfees", "rr_s_nfafees", "rr_s_clearingfees",
                "rr_s_ccy", "rr_d_statementdate", "rr_s_tradetype", "rr_d_tradedate", "rr_s_customaccountname",
                "rr_s_jpmaccountname", "rr_s_buysellpriority", "rr_s_volume", "rr_s_exchangename", "rr_i_exchangecode",
                "rr_s_contractdescription", "rr_s_instrumentcode", "rr_s_putcall", "rr_f_strike_1", "rr_s_accounttype",
                "rr_s_adjustmentdescription1", "rr_s_adjustmentdescription2", "rr_s_adjustmentdescription3",
                "rr_s_category", "rr_s_clearingfee", "rr_s_clearingfeecurrency", "rr_s_commissioncurrency",
                "rr_s_commissionjapanese", "rr_s_commissionjapanesecurrency", "rr_s_equitydescription",
                "rr_s_exchangefees", "rr_s_exchangefeescurrency", "rr_s_exchangetax", "rr_s_exchangetaxcurrency",
                "rr_s_exchangetradereference", "rr_i_executingbrokerid", "rr_s_executionfeecurrency", "rr_s_giveinfee",
                "rr_s_giveinfeecurrency", "rr_s_globexjvfee", "rr_s_globexjvfeecurrency", "rr_s_giveoutfee",
                "rr_s_giveoutfeecurrency", "rr_s_goodsservicestax", "rr_s_goodsservicestaxcurrency",
                "rr_s_instrumenttype", "rr_s_japaneseconsumptiontax", "rr_s_japaneseconsumptiontaxccy",
                "rr_s_nfafeescurrency", "rr_s_occfee", "rr_s_occfeecurrency", "rr_i_recordnumber", "rr_s_reutersfee",
                "rr_s_reutersfeecurrency", "rr_s_settlementdate", "rr_s_tradedescription1", "rr_s_tradedescription2",
                "rr_s_transactionfee", "rr_s_transactionfeecurrency", "rr_s_transactionsourcetype",
                "rr_s_valueaddedtax", "rr_s_valueaddedtaxcurrency", "rr_s_maturitydateofthetrades",
                "rr_f_exportabletradeprice", "rl_s_issuercode", "f_nominal_inicial", "s_tipo_de_condiciones_de_inter_s",
                "rr_s_tipo_final_fondeo", "rr_s_contrapartida_entidad", "rr_s_codigo_contrapartida_titular",
                "rr_s_codigo_cif", "rr_d_fecha_inicio_participacin", "rr_d_fecha_fin_participacin", "rr_d_fecha_inicio",
                "rr_d_fecha_fin", "rr_d_fecha_liquidacion", "rr_s_saldo_vivo", "rr_s_coste_fondeo",
                "rr_s_tipo_liquidaci_n_de_inter_s", "rr_d_fecha_primer_inter_s", "rr_d_fecha__ltimo_inter_s",
                "rr_d_fecha_pr_ximo_inter_s", "rr_d_fecha_proxima_renovaci_n", "rr_s_margen", "rr_s_tipo_base",
                "rr_s_tipo_final", "rr_s_importe_cuota_final", "rr_d_fecha_fin_inicial",
                "rr_s_indicador_de_venta_de_cartera", "rr_s_plazo_vida_media_fondeo", "cf_d_finicio", "cf_d_fvenci",
                "s_mandatory_match_field", "rl_s_notional_currency_1",
                "rl_s_effective_date_of_the_notional_amount_of_leg_1", "rl_s_end_date_of_the_notional_amount_of_leg_1",
                "rl_s_notional_amount_in_effect_on_associated_effective_date_of_leg_1", "rl_s_notional_amount_of_leg_2",
                "rl_s_notional_currency_2", "rl_s_effective_date_of_the_notional_amount_of_leg_2",
                "rl_s_end_date_of_the_notional_amount_of_leg_2",
                "rl_s_notional_amount_in_effect_on_associated_effective_date_of_leg_2",
                "rl_s_total_notional_quantity_of_leg_1",
                "rl_s_notional_quantity_in_effect_on_associated_effective_date_of_leg_1",
                "rl_s_effective_date_of_the_notional_quantity_of_leg_1",
                "rl_s_end_date_of_the_notional_quantity_of_leg_1", "rl_s_total_notional_quantity_of_leg_2",
                "rl_s_notional_quantity_in_effect_on_associated_effective_date_of_leg_2",
                "rl_s_effective_date_of_the_notional_quantity_of_leg_2",
                "rl_s_end_date_of_the_notional_quantity_of_leg_2", "rl_s_delivery_type", "rl_s_execution_timestamp",
                "rl_s_effective_date", "rl_s_expiration_date", "rl_s_early_termination_date",
                "rl_s_final_contractual_settlement_date", "rl_s_master_agreement_type", "rl_s_master_agreement_version",
                "rl_s_other_master_agreement_type", "rl_s_ptrr", "rl_s_type_of_ptrr_technique",
                "rl_s_ptrr_service_provider", "rl_s_event_type", "rl_s_ptrr_id", "rl_s_event_date", "rl_s_confirmed",
                "rl_s_confirmation_timestamp", "rl_s_clearing_obligation", "rl_s_cleared", "rl_s_central_counterparty",
                "rl_s_clearing_timestamp", "rl_s_intragroup", "rl_s_fixed_rate_of_leg_1_or_coupon",
                "rl_s_fixed_rate_or_coupon_day_count", "rl_s_fixed_rate_or_coupon_payment_frequency_period_leg_1",
                "rl_s_fixed_rate_or_coupon_payment_frequency_period_multiplier_leg_1",
                "rl_s_identifier_of_the_floating_rate_of_leg_1", "rl_s_name_of_the_floating_rate_of_leg_1",
                "rl_s_indicator_of_the_floating_rate_of_leg_1",
                "rl_s_floating_rate_reference_period_of_leg_1_time_period",
                "rl_s_floating_rate_reference_period_of_leg_1_multiplier", "rl_s_spread_of_leg_1",
                "rl_s_spread_currency_of_leg_1", "rl_s_floating_rate_day_count_convention_of_leg_1",
                "rl_s_floating_rate_payment_frequency_period_of_leg_1",
                "rl_s_floating_rate_payment_frequency_period_multiplier_of_leg_1",
                "rl_s_floating_rate_reset_frequency_period_of_leg_1",
                "rl_s_floating_rate_reset_frequency_multiplier_of_leg_1", "rl_s_fixed_rate_of_leg_2",
                "rl_s_fixed_rate_day_count_convention_leg_2", "rl_s_fixed_rate_payment_frequency_period_leg_2",
                "rl_s_fixed_rate_payment_frequency_period_multiplier_leg_2",
                "rl_s_identifier_of_the_floating_rate_of_leg_2", "rl_s_name_of_the_floating_rate_of_leg_2",
                "rl_s_indicator_of_the_floating_rate_of_leg_2",
                "rl_s_floating_rate_reference_period_of_leg_2_time_period",
                "rl_s_floating_rate_reference_period_of_leg_2_multiplier", "rl_s_spread_of_leg_2",
                "rl_s_spread_currency_of_leg_2", "rl_s_floating_rate_day_count_convention_of_leg_2",
                "rl_s_floating_rate_payment_frequency_period_of_leg_2",
                "rl_s_floating_rate_payment_frequency_period_multiplier_of_leg_2",
                "rl_s_floating_rate_reset_frequency_period_of_leg_2",
                "rl_s_floating_rate_reset_frequency_multiplier_of_leg_2", "rl_s_exchange_rate_1",
                "rl_s_forward_exchange_rate", "rl_s_exchange_rate_basis", "rl_s_strike_price_currencycurrency_pair",
                "rl_s_base_product", "rl_s_further_subproduct", "rl_s_subproduct", "rl_s_option_type",
                "rl_s_option_style", "rl_s_strike_price", "rl_s_effective_date_of_the_strike_price",
                "rl_s_end_date_of_the_strike_price", "rl_s_strike_price_in_effect_on_associated_effective_date",
                "rl_s_option_premium_amount", "rl_s_option_premium_currency", "rl_s_option_premium_payment_date",
                "rl_s_maturity_date_of_the_underlying", "rl_s_delivery_point_or_zone", "rl_s_interconnection_point",
                "rl_s_load_type", "rl_s_delivery_interval_start_time", "rl_s_delivery_interval_end_time",
                "rl_s_delivery_start_date", "rl_s_delivery_end_date", "rl_s_duration", "rl_s_days_of_the_week",
                "rl_s_delivery_capacity", "rl_s_quantity_unit", "rl_s_pricetime_interval_quantity",
                "rl_s_currency_of_the_pricetime_interval_quantity", "rl_s_seniority", "rl_s_reference_entity",
                "rl_s_series", "rl_s_version", "rl_s_index_factor", "rl_s_tranche", "rl_s_cds_index_attachment_point",
                "rl_s_cds_index_detachment_point", "rl_s_other_payment_amount", "rl_s_other_payment_currency",
                "rl_s_other_payment_type", "rl_s_other_payment_date", "rl_s_other_payment_payer",
                "rl_s_other_payment_receiver", "rl_s_package_identifier", "rl_s_package_transaction_price",
                "rl_s_package_transaction_price_currency", "rl_s_package_transaction_spread",
                "rl_s_package_transaction_spread_currency", "rl_s_action_type", "rl_s_level", "rl_s_file_date",
                "rr_s_cob_date", "rr_s_14counterparty_1_reporting_counterparty", "rr_s_117direction",
                "rr_s_221valuation_amount", "rr_s_222valuation_currency", "rr_s_25product_identification_type",
                "rr_s_27isin", "rr_s_21uti", "rr_s_241venue_of_execution", "rr_s_248price",
                "rr_s_260total_notional_quantity_of_leg_1", "rr_s_2132option_type", "rr_s_2134strike_price",
                "rr_s_2154level", "rr_s_clearing_member_code", "rr_s_tradingmembercode", "rr_s_exchangeaccountcode",
                "rr_s_positionaccountowners", "rr_s_exchangeproductcode", "rr_s_244expiration_date", "rr_s_23prior_uti",
                "rr_s_214underlying_identification", "rr_s_225delta", "rr_s_242execution_timestamp",
                "rr_s_248price_notation", "rr_s_255notional_amount", "rr_s_256notional_amount_currency",
                "rr_s_field_28", "rl_s_contractid", "rr_s_divisa_compra", "rr_f_cantidad_compra", "rr_s_divisa_venta",
                "rl_d_fecha_pago_flujo", "rr_d_fecha_maturity", "f_face_value", "f_nominal_pendiente_de_amortizar",
                "rl_f_field_7", "rl_d_mfvalue", "rl_s_fijovariable", "rl_d_fixdate", "rl_d_start_date_flujo",
                "rl_d_end_date_flujo", "cf_d_fv_abaco", "cf_s_calculated_result_4", "rl_i_dc5_aux",
                "rl_s_instrumento_2", "cf_f_calculated_result_4", "s_comentario", "s_roll_up_aux",
                "rl_s_status_boleta_front", "rl_d_field_14", "rl_d_field_20", "d_fechacalculo_1", "d_maturitydate_1",
                "s_isin_1", "f_nocional", "d_firstaccrualdate_1", "d_firstaccrualdate_2", "d_coupon_schedule1",
                "d_coupon_schedule3", "d_coupon_schedule2", "rl_s_c_digo_aplicaci_n_origen", "s_signo_cantidad",
                "s_star", "s_murex", "d_fechafijacion", "s_id___rerate_migrado", "rl_f_dirty_price_factorizado",
                "rl_s_m_tip_prod", "s_ado", "s_adotemplate", "s_currentunitnominal", "s_structure",
                "rr_f_currentnominal", "rl_s_m_tipology", "rr_s_dividend_swap", "d_fecha_fijacion", "d_fecha_calculo",
                "s_origen_2", "s_calypso", "rr_s_divisa_liquidaci_n", "f_porcentaje", "rr_d_stubstart",
                "rr_d_dated_date", "rr_d_fecha_fijacion", "rr_d_fixingdate", "cf_s_fijo_variable", "rl_s_currency_from",
                "rl_s_currency_to", "rr_s_currency", "rr_s_currency_from", "rl_f_total_amount", "rl_f_amount_from",
                "rl_f_amount_to", "rr_f_total_amount", "rr_f_amount_from", "rr_f_amount_to", "rl_f_lastqty", "rl_f_ccv",
                "cf_d_calculated_result_1", "cf_d_calculated_result_2", "cf_d_calculated_result_3",
                "cf_d_calculated_result_4", "cf_d_calculated_result_5", "cf_f_calculated_result_6",
                "cf_s_n_operacion_original", "cf_s_evento", "cf_s_estado_operacion", "rr_i_operacion",
                "f_primer_nominal", "f_segundo_nominal", "rl_s_situaci_n_operaci_n", "rr_s_libro_asignado",
                "rl_s_fecha_inicio", "rr_d_fecvalor", "f_primer_nominal_crv_eur", "f_segundo_nominal_crv_eur",
                "s_strategy", "f_cashflow", "f_cashflow_crv_eur", "dt_payment_date",
                "rl_s_clearing_threshold_of_counterparty_1",
                "rl_s_directly_linked_to_commercial_activity_or_treasury_financing", "rl_s_direction_of_leg_1",
                "rl_s_direction_of_leg_2", "rl_s_counterparty_2_identifier_type", "rl_s_counterparty_2",
                "rl_s_country_of_the_counterparty_2", "rl_s_nature_of_the_counterparty_2",
                "rl_s_corporate_sector_of_the_counterparty_2", "rl_s_clearing_threshold_of_counterparty_2",
                "rl_s_reporting_obligation_of_the_counterparty_2", "rl_s_broker_id", "rl_s_clearing_member",
                "rl_s_entity_responsible_for_reporting", "rl_s_valuation_amount", "rl_s_valuation_currency",
                "rl_s_valuation_timestamp", "rl_s_valuation_method", "rl_s_delta", "rl_s_reporting_timestamp",
                "rl_s_product_classification", "rl_s_unique_product_identifier_upi",
                "rl_s_underlying_identification_type", "rl_s_custom_basket_code",
                "rl_s_identifier_of_the_baskets_constituents", "rl_s_name_of_the_underlying_index",
                "rl_s_indicator_of_the_underlying_index", "rl_s_settlement_currency_1", "rl_s_settlement_currency_2",
                "rl_s_derivative_based_on_cryptoassets", "rl_s_prior_uti", "rl_s_subsequent_position_uti",
                "rl_s_collateral_portfolio_indicator", "rl_s_collateral_portfolio_code", "rl_s_report_tracking_number",
                "rl_s_venue_of_execution", "rl_s_price_currency", "rl_s_unadjusted_effective_date_of_the_price",
                "rl_s_unadjusted_end_date_of_the_price",
                "rl_s_price_in_effect_between_the_unadjusted_effective_and_end_date", "rl_s_price_multiplier",
                "rl_s_notional_amount_of_leg_1", "rl_s_counterparty_1", "d_issuedate", "f_initunitnominal",
                "s_bondlegfreqperiodcode", "d_finalcoupondate", "s_referenceindex", "s_liquidityspread", "s_iscovered",
                "i_importe", "s_direccion", "s_payment_date", "s_volcker_desk_class", "rl_s_root",
                "rl_s_processing_center", "rl_s_entity_set", "rl_s_closing_entity", "rl_s_processing_area",
                "rl_s_frtb_desk", "rl_s_auxiliar", "rr_s_portfoliocode", "rr_s_idportfoliotype", "rr_s_idtype",
                "s_202505310001099700017903100055972_10806030908050_r051806_410333000000000007421",
                "cf_f_suma_cantidad", "rr_d_end_date___operaci_n", "rr_s_trade_status", "cf_s_logs",
                "rl_s_n__oper__front", "rr_s_name_algorithmics", "rl_s_salesman_toms",
                "rl_s_salesperson_description_toms", "rl_s_trader_borkertec_usa___dealerweb", "rl_s_trader_glmx",
                "d_fecha_inicio_2", "d_fecha_vencimiento_2", "d_fecha_inicio_3", "d_fecha_vencimiento_3", "s_nominal_2",
                "cf_s_calculated_result_3", "cf_s_calculated_result_5", "cf_s_calculated_result_6", "f_nominal_st",
                "d_fecha_inicio_st", "d_fecha_vencimiento_st", "d_fecha_inicio_mx", "d_fecha_vencimiento_mx",
                "f_nominal_mx", "s_id_go_live_2", "s_origen_fo", "s_numero_operacion_", "s_numero_contrato_",
                "rr_s_trade_keyword_primaryassetclass", "rl_s_tradeno", "rl_s_id_tradeweb", "rl_dt_start_date_tradeweb",
                "rl_dt_tradedate_tradeweb", "s_settle_date", "f_outstanding", "d_stubstart", "d_dateddate",
                "d_fecha_inicio_devengo", "rr_s_tipo_de_evento", "rr_s_trade_keyword__packageid",
                "rr_d_dateiniciodevengo", "rr_s_coupon_currency", "rr_s_quotingcurrency", "rr_s_amortcurrency",
                "s_numfront_rollup", "s_bondmargin", "rl_s_market_sector_des", "rl_s_calendar_mortgage",
                "rl_s_is_perpetual", "rl_s_final_redemption_date", "rl_s_call_date", "rl_s_tipo_difusion_esb",
                "rl_s_underlying_index", "rl_s_me_id_tipo", "rl_d_final_redemption_date", "rl_i_issued_amount",
                "rl_s_issued_amount", "cf_f_dirty_price_murex", "rl_f_tipo_de_inter_s", "rl_f_spread", "s_amort_curr",
                "rr_s_identificador_movimiento_base", "s_redemption_curr", "s_initial_currency", "rr_d_dateliquidacion",
                "rr_d_paymentdate", "s_flipper_coupon", "rl_s_bond_fixing_position", "s_root", "s_volcker_desk_class_2",
                "rl_i_processing_area", "s_tipo_de_porfolio", "s_calendario_titularizaciones",
                "s_calendario_no_titularizaciones", "s_divisa_cupon", "s_divisa_amortizaci_n",
                "s_divisa_amortizaci_n_total", "s_divisa_emisi_n", "s_posid", "f_nominal_nuevo", "s_geografia",
                "cf_f_amount_crv_eur_jbpm_artika", "rr_s_fecha_fixing", "rl_s_dtflownat", "rr_d_fecha_fixing",
                "rr_d_fecha_payment_date", "s_ccp", "d_enddate", "s_sistema_origen", "s_c_digo_fo_de_contrapartida",
                "f_tipo_fijo_pata_de_pago", "s_indice_de_referencia_pata_pago", "f_spread_pata_de_pago",
                "f_tipo_fijo_pata_de_cobro", "s_indice_de_referencia_pata_cobro", "f_spread_pata_de_cobro",
                "rl_s_codecounterparty", "rr_s_codecounterparty", "rl_i_resetdays", "rl_f_issued_amount",
                "rl_f_resetdays", "rl_s_36051_mxmad_4517740_4517740eureu", "s_description", "d_announcedate",
                "d_greymarketdate", "s_appliedrule", "s_idbbglobalcompany", "s_exchange", "s_exchangelei", "s_country",
                "s_initialcurrency", "s_mindealamount", "s_initprice", "s_seniority", "s_centralanotacion",
                "s_idstarlatam", "s_mic", "i_exdivdays", "f_referencecpi", "s_isblindmarket", "s_bdecode", "s_common",
                "s_segregabletype", "s_isguaranteed", "s_isquoted", "s_assimdate", "i_redeemdays", "d_calcmaturity",
                "s_isperpetual", "s_bondtoeqyticker", "s_parenttickerexchange", "s_industrysector", "s_industrygroup",
                "s_idbbglobal", "s_isunittraded", "s_ifrs9sppitest", "s_couponratedec", "s_coupondecround",
                "s_exchmarketstatus", "s_guarantorlei", "s_guarantoridfiscal", "s_cntryissueiso", "s_countryfullname",
                "s_aplicacintasaumbral", "s_issuerorgid", "s_assettype", "s_registrar", "s_registrarlei",
                "s_csdnamelei", "s_comdeporservprovlei", "s_assetsubtype", "s_labelmurex", "s_issuergroupbce",
                "s_redemptionvalue", "s_amortcurr", "s_isconvertible", "s_redemptioncurr", "s_basicpointvalue",
                "s_bbnum", "s_bndquotetype", "d_currchangedate", "s_marketname", "s_ratingissuer", "s_ratingissuer_2",
                "s_ratingmoodys", "s_ratingsp", "s_ispreferred", "s_convertibletyp", "s_capitalgarantizado",
                "s_ratingmifid", "s_familiamifid", "s_clasificacionmifid", "s_mifidbailin", "s_rtgsp", "s_rtgmoody",
                "d_rtgsplongratingdt", "s_clientkey", "s_extentype", "s_filterexception", "s_instrumenttype",
                "s_isdeliverable", "s_meidcarga", "s_basecurve", "s_basecurvegov", "s_basecurveirs",
                "s_creditspreadcalc", "s_isliquid", "s_liquiditygrade", "f_liquidityspread", "s_optionsvalue",
                "s_selectionrule", "s_askfieldname", "s_issuestforrisks", "s_mecalcestimatedcoupon",
                "s_codvalorrazonable", "s_idisin", "s_paymentrank", "s_lowertier2capital", "s_marketsectordes",
                "s_collattyp", "s_issuer", "s_guarantorname", "s_defaulted", "d_defaultdate", "s_cntryofdomicile",
                "f_conversionpriceatissu", "s_issuerindustry", "s_issuerparenteqyticker", "s_registrationidentifier",
                "s_adolongname", "s_observations", "s_retentionperc", "s_yieldfreq", "s_yieldbasis", "s_tipcalc",
                "i_slidingdaysbond", "s_slidingdaysbondtype", "s_prodgroupstar", "s_prodgroupabaco", "s_starmarket",
                "s_yieldind", "s_rolldays", "s_paydelay", "s_paydelay_2", "s_adoparent", "s_bondtype", "s_depocode",
                "s_assimproduct", "s_mtgpaydelay", "s_tier2capitalnonspecif", "s_senior", "s_tipoliquidacion",
                "s_tasaceremision", "s_attrevitarvencimiento", "s_csdname", "s_coupontype", "s_ric",
                "s_isstructurednote", "s_prodgroupnscv", "d_rtgmdylongratingdt", "s_warrantcode", "s_riskpremium",
                "s_theopricecalc", "s_theopriceinterp", "s_selectionruledepo", "s_issubor", "s_parsekyabledes",
                "s_tier1capital", "s_uppertier2capital", "d_reinstateddate", "s_typeofbond", "f_yieldonissuedate",
                "s_name", "s_maturitybloomb", "s_ticker", "s_calendarcode", "f_paramt", "s_securityresolutiontype",
                "s_securitypayagelei", "s_legalentityidentifier", "s_sftrissuerjurisdiction", "s_sftrsecuritytype",
                "s_sftrcollissuerjuris", "s_sftrcollateraltype", "s_sftrsecurityquality", "s_sftrcollateralquality",
                "s_cficode", "rl_f_dc2_financing", "rl_f_dc3_efecto_fx", "rl_f_dc4_tipo_cambio", "rl_f_dc5_autocartera",
                "rl_f_pl_cajas_mes_eur", "rl_f_pl_mes_eur", "rl_f_pl_mes_eur_dividendos", "rl_f_pl_valoracion_mes_eur",
                "rl_f_resultado_sigma_perimetro_comparable", "rl_f_resultado_sigma_perimetro_publicable",
                "rl_s_cod_apl_origen", "rr_f_ajustes_manuales_7250_boco", "rr_f_ajustes_manuales_7250_recla",
                "rr_f_ajustes_manuales_7250_resto", "rr_f_ajustes_manuales_7250_signo", "rr_f_ajustes_masivos",
                "rr_f_ajustes_masivos_boco", "rr_f_ajustes_masivos_recla", "rr_f_ajustes_masivos_resto",
                "rr_s_clasificacion_ajuste", "rr_f_dc6_ajustes_liq_amiga", "rr_f_de_diferencias_explicadas",
                "rr_f_de1_ajustes_7250", "rr_f_de2_ajustes_masivos", "rr_f_pl_resultado_contable",
                "rr_f_resultado_aplicaciones_bo", "rr_f_resultado_contable_publicado", "rl_s_section", "rl_d_issuedate",
                "rl_d_maturitydate", "s_greymarketdate", "s_slidingdaysbond", "s_calcmaturity",
                "rl_f_dc_diferencias_de_criterio", "rr_f_dc_diferencias_de_criterio", "rl_i_apuntes", "rr_i_apuntes",
                "s_currchangedate", "s_defaultdate", "s_yieldonissuedate", "s_paramt", "d_fecha_emision",
                "rl_f_importe_apunte", "rl_s_etiquetas_pencru", "rl_i_pencru_aux", "rl_s_divisa_origen",
                "rl_s_codigo_importe", "rl_s_divisa_importe", "rl_s_lado_origen", "rr_f_importe_apunte",
                "rr_s_etiquetas_pencru", "rr_i_pencru_aux", "rr_s_codigo_importe", "rr_s_divisa_importe",
                "rr_s_lado_origen", "f_cpn", "d_lastcoupondate", "rl_s_isperpetual", "s_frecuencia_cup_n",
                "s_base_c_lculo", "rl_s_inflationind", "rl_i_idperimeter", "rl_i_idlegalentity", "s_processing",
                "rl_s_idtype", "rl_s_idperimeter", "rl_s_idlegalentity", "rl_s_idgeography", "rl_s_idportfoliotype",
                "rl_s_idrequestedportfoliosystem", "rl_s_btcrea", "rl_s_idusersxbtcrea", "rl_s_idwfstatus",
                "rl_s_idaccountingoffice", "rl_s_marketsectordes", "rl_s_meidtipo", "rl_s_tipoemision",
                "s_nominal_incial", "d_fecha_emisi_n", "d_firstcoupondate", "rr_d_calendario_de_amortizacion",
                "rr_s_spread", "f_last_coupon_rate", "s_couponcurr", "s_frecuencia_cupon", "s_n_mero_star",
                "rr_s_n_deal_midas", "s_producto_midas", "cf_s_equipo", "s_divisa_entrada", "f_total_intereses",
                "rl_s_observaciones", "rl_s_aplicaci_n_origen", "rl_s_descripci_n", "cf_d_fecha_recon", "f_oficina",
                "s_c_digo_cliente", "cf_s_origen", "rr_s_dealogic_group", "rr_s_entity_set", "rr_s_accounting_section",
                "s_geography", "s_legal_entity", "s_perimeter", "s_requested_portfolio_system", "s_creation_user",
                "s_creation_date", "s_cob_date", "i_prima_de_liquidez_aux", "i_apuntes_prima_aux", "s_brokertec_usa",
                "rl_f_rst_dia_crv", "f_rst_dia_eur", "f_rst_ann_crv", "s_tipooperativamurex", "f_importeoperacion",
                "d_fechaliquidacion", "s_divisamovimiento", "i_cdigooficinacs", "s_codempresa", "s_codigo_empresa",
                "d_fecha_liquidacion", "rl_s_nombre_entidad", "rl_i_codigo_entidad", "rl_s_nombre_oficina",
                "rl_s_nombre_patron_movimiento", "rl_s_nombre_contrapartida", "rl_i_numero_expediente",
                "rl_d_id_contrato", "rl_s_nombre_tramo", "rl_s_id_movimiento", "rl_i_id_contrato", "rl_d_mtpdtetrn",
                "rl_s_mevtdlabel", "rl_d_mtpdteexp", "rl_s_numero_expediente", "rl_s_id_contrato", "s_ratingfitch",
                "s_attrcontingentconver", "s_attrcvcnvsratio", "s_rtgfitch", "s_rtgdbrs", "s_rtgscope",
                "d_rtgfitchlongratingdt", "s_rtgscopeltissuedt", "s_mifidisadmittedtotra", "s_mifidunderlyistotv",
                "d_mifidatteffectivedate", "s_guarantor", "s_multicontrib", "s_creditspreadcrvman",
                "s_baseliiidesignation", "s_capitaltypcocoinitri", "s_mtytyp", "s_extendible",
                "s_bailinbonddesignation", "s_calctypdes", "s_securityshortdes", "s_mtgispaidoff", "s_isunsecured",
                "s_issecured", "s_normalizedpaymentrank", "s_mtgtyp", "s_reinstateddate", "f_mtgwal",
                "s_capitalcontingentsecur", "s_certunderlyingtype", "s_ciccategory", "s_convpricereset", "f_fltspread",
                "s_fundtyp", "s_issuespreadbnchmrk", "f_mtgfirstcpn", "s_munitaxprov", "s_optundlticker",
                "s_seriesamountoutstandin", "f_totdebttototasset", "f_amtissued", "f_cvcnvspx",
                "s_convbyissuerorholder", "s_putable", "s_securitytyp", "s_shortname", "s_rtgspltlcissuercred",
                "s_rtgspltfcissuercred", "s_rtgmdylccurrissurat", "s_rtgmdyfccurrissurat", "s_rtgmdyltlcdebtrat",
                "s_rtgmdyltfcdebtrat", "s_rtgfitchltlcissudef", "s_rtgfitchltfcissudef", "s_lqaliquidityscore",
                "s_extendibleisstillexte", "s_isstillcallable", "d_lastcallabledate", "d_nxtputdt", "s_nxtputpx",
                "s_guarantylevel", "s_idbbglobalguarantco", "s_mtgamorttyp", "s_called", "s_cpntypspecific",
                "s_firstcpnperiodtyp", "d_nxtcalldt", "rr_s_primary_asset_class", "s_prueba_fecha", "s_bsk_end_date",
                "s_contract", "rr_f_resultado_bo_revaluacion", "rl_f_resultado_sigma_perimetro_comparable_revaluacion",
                "cf_f_resultado_sigma_perimetro_comparable_rof",
                "f_resultado_sigma_perimetro_comparable_revaluacion_aux",
                "cf_f_resultado_sigma_perimetro_comparable_rof_aux", "cf_f_resultado_bo_revaluacion",
                "cf_f_resultado_sigma_perimetro_comparable_revaluacion", "rl_s_concepto_cg_folio", "rr_s_serv_creador",
                "rl_s_producto_gestion", "rl_s_marca_contable", "rr_s_tipo_procedencia", "rr_s_tipo_contrato",
                "rl_f_nominal_vivo", "rr_s_producto_gestion", "rr_s_marca_contable", "rl_s_tipo_procedencia",
                "rl_s_serv_creador", "rl_s_tipo_contrato", "rl_s_clasificacion_cuenta", "rr_s_expediente_clan",
                "rr_s_tramo_clan", "s_bocf", "rr_s_id_garant_a__nico", "s_tipo_garantia", "s_grupo_tipo_de_garantia",
                "s_nif_garante", "s_nombre_garante", "s_cobertura", "rr_f_importe_nominal_vivo_expedientet",
                "f_importe_garantia", "f_importe_calculado", "s_libro", "s_tomo", "s_finca", "s_idufir",
                "s_cuenta_de_valores_en_prendas", "s_n_expediente_clan", "rl_i_facility", "rr_s_marca_publicable",
                "rr_f_dc13_dop_sla", "s_nombre_del_cliente", "s_nif_del_cliente", "s_fecha_fin_facility",
                "rr_s_rendimiento", "rr_s_tipo_de_rendimiento", "s_fichero_origen", "rr_s_numback",
                "rr_s_fecha_contratacion", "rl_s_cartera_mes_actual", "rl_s_cartera_mes_anterior",
                "rr_s_cartera_mes_actual", "rr_s_cartera_mes_anterior", "rl_s_fecha_valor", "rr_s_fecha_valor",
                "rl_s_divisa_operacion", "rl_s_codigo_divisa", "rl_s_codigo_origen", "rr_s_marca_macro_coberturas",
                "rl_s_codigo_producto", "rr_s_codigo_producto", "s_tipo_de_movimiento___account_code",
                "cf_f_cash_flow_crv_murex", "cf_f_cash_flow_crv_calypso", "rr_s_n__deal_midas", "rl_s_estado_interfase",
                "s_redemptionbasis", "f_basecpi", "s_settledtcpi", "s_redenombyissuer", "s_hasbondfactor",
                "f_mtgorigwal", "f_mtgorigwal_2", "s_segregable", "s_stripagregdate", "s_stripagregdate_2",
                "s_stripsegregdate", "s_striptype", "s_usagefilteram", "s_usagefilteram_2", "s_mtgcmoclass",
                "d_bankruptcydate", "s_cntryofrisk", "f_ddisamtoutsissuesubs", "s_bondrecoveryrate",
                "s_loanoriginatorname", "s_isocountryguarantor", "s_sinktyp", "s_amortizationtypedesc", "i_sinkfreq",
                "i_fltlockoutdays", "s_securityfactorable", "s_mtgdealtyp", "s_mtgprepaymodel", "s_mtgprepayspdtyp",
                "s_mtgtranchetyp", "s_tranchecode", "s_greenbondflag", "s_eutaxflag", "s_icmaalignbond", "s_security",
                "s_multimarket", "s_usagefilterusa", "rr_f_intereses_periori", "rr_d_fecha_pago_int", "rr_s_subtipo",
                "rr_f_intereses_periodificados", "rr_d_siguiente_fecha_pago_intereses", "s_accounting_office",
                "s_trade_mandate", "rl_s_redemption_basis", "update_date"]

# %%
def formatter(fields):

  processed_matched_fields = []
  for field in fields:
      lowercase_field = field.lower()
      processed_field = re.sub(r'[^a-z0-9_]+', '_', lowercase_field)
      processed_matched_fields.append(processed_field)
  return processed_matched_fields

# %%
def format_field_to_title_case(field, acronyms=set()):

  words = field.split('_')

  processed_words = []
  for word in words:
    if word.lower() in acronyms:
      processed_words.append(word.upper())
    else:
      processed_words.append(word.capitalize())

  formatted_field = '_'.join(processed_words)

  return formatted_field

special_acronyms = {'dc2', 'dc3', 'fx', 'dc4', 'dc7', 'de1', 'de2', 'de3', 'pl',
                    'eur', 'bo', 'dc', 'de', 'dc1', 'boco', 'isin', 'dc13',
                    'dop', 'sla', 'cpty', 'ge', 'rof', 'fobo',
}

# %% [markdown]
# # codigo

# %%
matched_fields_string = "Grupo_Cruce, Codigo_Producto, Importe, Codigo_Importe, DC2_Financing, DC3_Efecto_FX, \
DC4_Tipo_Cambio, DC7_Intimas, DE1_Ajustes_7250, DE2_Ajustes_Masivos, DE3_Otros, PL_RESULTADO_CONTABLE, \
PL_MES_EUR, PL_CAJAS_MES_EUR, PL_VALORACION_MES_EUR, Resultado_Sigma_Perimetro_Comparable, \
Resultado_Sigma_Perimetro_Publicable, Resultado_Aplicaciones_BO, Resultado_Contable_Publicado, \
DC_Diferencias_de_Criterio, DE_Diferencias_Explicadas, DC1_Diferencia_de_Perimetro, Apuntes, \
Ajustes_Manuales_7250_Signo, Ajustes_Masivos, Ajustes_Manuales_7250_BOCO, Ajustes_Manuales_7250_Recla, \
Ajustes_Manuales_7250_Resto, Ajustes_Masivos_BOCO, Ajustes_Masivos_Recla, Ajustes_Masivos_Resto, Lado_Origen, \
Divisa_Importe, Comentario_Pencru, Etiquetas_Pencru, Pencru aux, Divisa_Origen, Clasificacion_Ajuste, \
Numfront_Tratado, Importe_Apunte, Cod_Apl_Origen, Numfront, ISIN, Resultado_BO_Revaluacion, DC13_DOP_SLA, \
Resultado_Sigma_Perimetro_Comparable_Revaluacion, Cartera_Mes_Actual, Cartera_Mes_Anterior, Estructura, \
Fecha_Vencimiento, Fecha_Valor, Contrapartida"

left_fields_string = "Producto_Gestion, Marca_PUBLICABLE, Marca_CONTABLE, Marca_AUTOCARTERA, Portfolio, Instrumento, \
Oficina_Unidad, Oficina_CPTY, Comentario_Ajuste_GE, Agrupa"

right_fields_string = "Tipo_BOCO, Tipologia_BOCO, Tipo_Procedencia, Oficina, Tipo_Contrato, Contrato, Cuenta, Serv_Creador, \
Clasificacion_Cuenta, Fecha_Vencimiento, Numback, Fecha_Contratacion"

calculated_fields_string = "Diferencias_No_Explicadas, Marca_Transitorias, Marca_FOBO, Operacion_Masa, Resultado_BO_ROF, \
Resultado_Sigma_Perimetro_Comparable_ROF"

matched_fields = matched_fields_string.split(", ")
left_fields = left_fields_string.split(", ")
right_fields = right_fields_string.split(", ")
calculated_fields = calculated_fields_string.split(", ")

# %% [markdown]
# ## MATCHED

# %%
import re

matched_fields = formatter(matched_fields)

candidatos_dict = {}

for field in matched_fields:
    # La condición ahora comprueba si 'col' empieza con 'rl_' Y termina con 'field'
    candidatos = [
        col for col in lista_columnas
        if not col.lower().startswith('rl_') and
            not col.lower().startswith('rr_') and
            not col.lower().startswith('cf_') and
            col.lower().endswith(field)
    ]
    candidatos_dict[format_field_to_title_case(field, special_acronyms)] = candidatos

matched_fields_query = "matched_fields = {\n"
for nombre, candidatos in candidatos_dict.items():
    candidatos_str = ', '.join(['r.' + col for col in candidatos])

    if len(candidatos) == 1:
        valor_final = candidatos_str
        comentario = ""
    else:
        valor_final = f"[{candidatos_str}]"
        comentario = " # TODO: Elegir valor correcto de la lista"

    matched_fields_query += f'\t"{nombre}": "{valor_final}",{comentario}\n'
matched_fields_query += "}"

# %% [markdown]
# ## LEFT

# %%
import re

left_fields = formatter(left_fields)

candidatos_dict = {}

for field in left_fields:
    # La condición ahora comprueba si 'col' empieza con 'rl_' Y termina con 'field'
    candidatos = [
        col for col in lista_columnas
        if col.lower().startswith('rl_') and
          col.lower().endswith(field)
    ]
    candidatos_dict[format_field_to_title_case(field, special_acronyms)] = candidatos

left_fields_query = "left_fields = {\n"
for nombre, candidatos in candidatos_dict.items():
    candidatos_str = ', '.join(['r.' + col for col in candidatos])

    if len(candidatos) == 1:
        valor_final = candidatos_str
        comentario = ""
    else:
        valor_final = f"[{candidatos_str}]"
        comentario = " # TODO: Elegir valor correcto de la lista"

    left_fields_query += f'\t"{nombre}": "{valor_final}",{comentario}\n'
left_fields_query += "}"

# %% [markdown]
# ## RIGHT

# %%
import re

right_fields = formatter(right_fields)

candidatos_dict = {}

for field in right_fields:
    # La condición ahora comprueba si 'col' empieza con 'rl_' Y termina con 'field'
    candidatos = [
        col for col in lista_columnas
        if col.lower().startswith('rr_') and
          col.lower().endswith(field)
    ]
    candidatos_dict[format_field_to_title_case(field, special_acronyms)] = candidatos

right_fields_query = "right_fields = {\n"
for nombre, candidatos in candidatos_dict.items():
    candidatos_str = ', '.join(['r.' + col for col in candidatos])

    if len(candidatos) == 1:
        valor_final = candidatos_str
        comentario = ""
    else:
        valor_final = f"[{candidatos_str}]"
        comentario = " # TODO: Elegir valor correcto de la lista"

    right_fields_query += f'\t"{nombre}": "{valor_final}",{comentario}\n'
right_fields_query += "}"

# %% [markdown]
# ## CALCULATED

# %%
import re

calculated_fields = formatter(calculated_fields)

candidatos_dict = {}

for field in calculated_fields:
    # La condición ahora comprueba si 'col' empieza con 'rl_' Y termina con 'field'
    candidatos = [
        col for col in lista_columnas
        if col.lower().startswith('cf_') and
          col.lower().endswith(field)
    ]
    candidatos_dict[format_field_to_title_case(field, special_acronyms)] = candidatos

calculated_fields_query = "calculated_fields = {\n"
for nombre, candidatos in candidatos_dict.items():
    candidatos_str = ', '.join(['r.' + col for col in candidatos])

    if len(candidatos) == 1:
        valor_final = candidatos_str
        comentario = ""
    else:
        valor_final = f"[{candidatos_str}]"
        comentario = " # TODO: Elegir valor correcto de la lista"

    calculated_fields_query += f'\t"{nombre}": "{valor_final}",{comentario}\n'
calculated_fields_query += "}"

# %% [markdown]
# ## PRINT

# %%
print(matched_fields_query)
print()
print(left_fields_query)
print()
print(right_fields_query)
print()
print(calculated_fields_query)
print()
# Out:
# matched_fields = {
# 	"Grupo_Cruce": "r.s_grupo_cruce",
# 	"Codigo_Producto": "r.s_codigo_producto",
# 	"Importe": "[r.f_importe, r.s_codimporte, r.s_importe, r.s_codigo_importe, r.s_divisa_importe, r.s_divisaimporte, r.s_codigoimporte, r.i_importe]", # TODO: Elegir valor correcto de la lista
# 	"Codigo_Importe": "r.s_codigo_importe",
# 	"DC2_Financing": "r.f_dc2_financing",
# 	"DC3_Efecto_FX": "r.f_dc3_efecto_fx",
# 	"DC4_Tipo_Cambio": "r.f_dc4_tipo_cambio",
# 	"DC7_Intimas": "r.f_dc7_intimas",
# 	"DE1_Ajustes_7250": "r.f_de1_ajustes_7250",
# 	"DE2_Ajustes_Masivos": "r.f_de2_ajustes_masivos",
# 	"DE3_Otros": "r.i_de3_otros",
# 	"PL_Resultado_Contable": "r.f_pl_resultado_contable",
# 	"PL_Mes_EUR": "r.f_pl_mes_eur",
# 	"PL_Cajas_Mes_EUR": "r.f_pl_cajas_mes_eur",
# 	"PL_Valoracion_Mes_EUR": "r.f_pl_valoracion_mes_eur",
# 	"Resultado_Sigma_Perimetro_Comparable": "r.f_resultado_sigma_perimetro_comparable",
# ...
